# %% [markdown]
# # T4MP Analyst. Тестовое задание

# %% [markdown]
# ## Задача:
#
# **Набор открытых данных**
#
# #### **Всероссийский реестр объектов спорта с видами спорта**
#
# [https://data.gov.ru/opendata/7703771271-sportobjects/data-20160714T0856-structure-20160714T0856.csv](https://data.gov.ru/opendata/7703771271-sportobjects/data-20160714T0856-structure-20160714T0856.csv)
#
# > Отчет подготовить в виде Jupyter Notebook
# >
#
# ### 1. EDA
#
#
# ### 2. **Подготовить срез данных по списку спортивных объектов, дополнить преобразованными или внешними данными:**
#
# - "Название" - строка, обязательно
#
# - "Адрес" - строка, обязательно
#
# - "Тип населенного пункта" ("город", "поселок" и т.д.) - строка, обязательно
#
# - "Почтовый индекс" - строка, опционально
#
# - "E-mail" - строка, обязательно
#
# - "Даты крупных соревнований и значимых событий" - строка, опционально
#
# - "Общий объём финансирования (руб.)" - целое число, обязательно
#
# - "Общий объём финансирования (EUR)" (по курсу ЦБ РФ, на дату выполнения задания) - целое число, опционально
#
# - "Общий объём финансирования (USD)" (по курсу ЦБ РФ на дату завершения строительства/реконструкции) - целое число, опционально
#
# - "Доля от объема финансирования в регионе" (от общего объема финансирования приведенных объектов того же субъекта федерации) - число, обязательно
#
# - "Продолжительность строительства/реконструкции (дней)" - целое число, опционально
#
# - "Наличие зимних олимписких видов спорта в видах спорта объекта" - булев тип, обязательно
#
#
# ### 3. **Отчет по субъектам федерации:**
#
# - "Субъект федерации" - строка, обязательно
#
# - "Количество спортивных объектов" - целое число, обязательно
#
# - "Суммарный объем финансирования - строительство (руб.)" - целое число, обязательно
#
# - "Перечень типов спортивных объеков" (отсортированных по алфавиту) - строка, обязательно
#
# - "ТОП-5 доступных видов спорта" (по представленности в объектах региона, с указанием числа объектов) - строка, обязательно
#
# ### 4. **Итоговый ноутбук выложить в закрытый репозиторий github, дать доступ аккаунту @AlxFltv**

# %% [markdown]
# <a name="1common."></a>
# ## <a name="0.0"></a>Содержание:
# * [0. Импорт библиотек и загрузка данных](#0.)
# * [1. EDA](#1.)
#     * [Базовая информация](#10.)
#     * [Проверка на полноту и адекватность](#100.)
#         * [Название](#11.)
#         * [Активный](#12.)
#         * [Адрес](#13.)
#         * [E-mail](#14.)
#         * [Общий объём финансирования (руб.)](#15.)
#         * [Тип спортивного комплекса](#16.)
#         * [Виды спорта](#17.)
#     * [Итог](#18.)
# * [2. Cрез данных по списку спортивных объектов](#2.)
#     * [Что необходимо досчитать?](#20.)
#         * [Тип населенного пункта](#21.)
#         * [Почтовый индекс](#22.)
#         * [Даты крупных соревнований и значимых событий](#23.)
#         * [Общий объём финансирования EUR и USD](#24.)
#         * [Доля от объема финансирования в регионе](#25.)
#         * [Продолжительность строительства/реконструкции (дней)](#26.)
#         * [Наличие зимних олимписких видов спорта в видах спорта объекта](#27.)
#     * [Итог](#28.)
# * [3. Отчет по субъектам федерации](#3.)
#     *
#         * [Суммарный объем финансирования - строительство (руб.)](#31.)
#         * [Количество спортивных объектов](#32.)
#         * [Перечень типов спортивных объеков](#33.)
#         * ["ТОП-5 доступных видов спорта"](#34.)
#     * [Итог](#35.)

# %% [markdown]
# ## 0. Импорт библиотек и загрузка данных
# <a name="0."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
#Импортируем все необходимые библиотеки

import numpy as np
import pandas as pd
import datetime
import itertools
import warnings

import matplotlib.pyplot as plt
import seaborn as sns
import re
import requests

from termcolor import colored
from bs4 import BeautifulSoup
from collections import Counter
from pymystem3 import Mystem
from validate_email import validate_email

user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'
headers = {'User-Agent': user_agent}

# %%
#Определяем болд
def bold(): 
    return "\033[1m"

def bold_end(): 
    return "\033[0m"

#Ставим формат для нумериков
pd.options.display.float_format = '{: >10.2f}'.format

# %%
#**Функция print_basic_info, для вывода информации о массиве, и его переменных.**

#* base - название базы данных
#* info - 1: вывод информации о массиве, другое: не вывод
#* describe - 1: вывод описания переменных массива, другое: не вывод        
#* duplicat - 1: вывод количества полных дублей
#* head - n: вывод примера базы (вывод n - строк), n < 1: не вывод

def print_basic_info(base, info, describe, duplicat, head):
    if info == 1:
        print("\n", bold(), colored('info','green'), bold_end(), "\n")
        print( base.info())  
    if head >= 1:
        print("\n", bold(),colored('head','green'),bold_end())
        display(base.head(head))
    if describe == 1:
        print("\n", bold(),colored('describe','green'),bold_end(),"\n")
        for i in base.columns:
            print("\n", bold(), colored(i,'blue'),bold_end(),"\n", base[i].describe())
    if duplicat == 1:
        print("\n", bold(),colored('duplicated','green'),bold_end(),"\n")
        print(base[base.duplicated() == True][base.columns[0]].count())

# %%
raw_data = pd.read_csv('https://data.gov.ru/opendata/7703771271-sportobjects/data-20160714T0856-structure-20160714T0856.csv',  sep=',',decimal='.')

# %% [markdown]
# ## 1. EDA
# <a name="1."></a>
# ### Базовая информация
# <a name="10."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
#распечатаем базовую инфо
print_basic_info(raw_data,1,0,0,5)
# Out:
#   info
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 810 entries, 0 to 844
# Data columns (total 24 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Название                                              810 non-null    object
#  1   Адрес                                                 810 non-null    object
#  2   Общий объём финансирования (руб.)                     810 non-null    float64
#  3   Виды спорта                                           810 non-null    object
#  4   Субъект федерации                                     810 non-null    object
#  5   Тип спортивного комплекса                             810 non-null    object
#  6   E-mail                                                458 non-null    object
#  7   Населённый пункт                                      810 non-null    object
#  8   Краткое описание                                      750 non-null    object
#  9   Детальное описание                                    634 non-null    object
#  10  Дата начала строительства / реконструкции             698 non-null    datetime64[ns]
#  11  Дата завершения строительства / реконструкции         797 non-null    datetime64[ns]
#  12  URL сайта                                             86 non-null     object
#  13  Финансирование из федерального бюджета                810 non-null    float64
#  14  Финансирование из бюджета субъекта федерации          810 non-null    float64
#  15  Финансирование из бюджета муниципального образования  810 non-null    float64
#  16  Финансирование из внебюджетных источников             810 non-null    float64
#  17  Активный                                              810 non-null    object
#  18  Действия с объектом                                   810 non-null    object
#  19  Общий объём финансирования. Проверка                  810 non-null    float64
#  20  sport_bool                                            810 non-null    object
#  21  Есть виды спорта                                      810 non-null    object
#  22  Описание                                              810 non-null    object
#  23  Виды спорта 2                                         810 non-null    object
# dtypes: datetime64[ns](2), float64(6), object(16)
# memory usage: 158.2+ KB
# None
#
#   head
#                                           Название  \
# 0      Крытый плавательный бассейн «Садко» СДЮСШОР
# 1                  Спортивный зал для мини-футбола
# 2                            Ледовый дворец спорта
# 3        Спортивный центр с плавательным бассейном
# 4  Спортивный центр с универсальным игровым залом
#
#                                                Адрес  \
# 0  Ханты-Мансийский автономный округ, г. Советски...
# 1  Ханты-Мансийский автономный округ, г. Лангепас...
# 2  Ханты - Мансийский автономный округ, г. Сургут...
# 3  Ханты-Мансийский автономный округ, пос. Лыхма,...
# 4  Ханты-Мансийский автономный округ-Югра, г. Лан...
#
#    Общий объём финансирования (руб.)  \
# 0                       147105000.00
# 1                        83829000.00
# 2                       814724600.00
# 3                       212165000.00
# 4                       143946000.00
#
#                                          Виды спорта    Субъект федерации  \
# 0                                           плавание  Ханты-Мансийский АО
# 1  игровые виды спорта (разное), мини-футбол, общ...  Ханты-Мансийский АО
# 2  аквааэробика, греко-римская борьба, общая физи...  Ханты-Мансийский АО
# 3                             аквааэробика, плавание  Ханты-Мансийский АО
# 4  баскетбол, бодибилдинг, волейбол, настольный т...  Ханты-Мансийский АО
#
#                  Тип спортивного комплекса                 E-mail  \
# 0                                  бассейн          ukmps@mail.ru
# 1                           зал спортивный                    NaN
# 2                            арена ледовая        lds2011@list.ru
# 3  многофункциональный спортивный комплекс  NurtdinovRA@admbel.ru
# 4  многофункциональный спортивный комплекс                    NaN
#
#   Населённый пункт                                   Краткое описание  \
# 0     г. Советский  МБОУ ДОД СДЮСШОР г. Советский единственное учр...
# 1      г. Лангепас  Отдельно стоящее здание, расположено на обособ...
# 2        г. Сургут  Ледовый Дворец спорта в городе Сургуте открыт ...
# 3       пос. Лыхма  Спортивный центр с плавательным бассейном в п....
# 4      г. Лангепас  Отдельно стоящее здание, расположено на обособ...
#
#                                   Детальное описание  ...  \
# 0  Общая площадь здания «Крытого плавательного ба...  ...
# 1  Здание кирпичное, бетонное, блоки «Сэндвичи». ...  ...
# 2  Общая площадь объекта составляет 21 247 м2. Пе...  ...
# 3  Общая площадь объекта составляет 2111 м2. Пере...  ...
# 4  Общая площадь объекта составляет 3092,8 м2. Пе...  ...
#
#   Финансирование из бюджета субъекта федерации  \
# 0                                 132844000.00
# 1                                  63014000.00
# 2                                   8293100.00
# 3                                 150646000.00
# 4                                 114058000.00
#
#   Финансирование из бюджета муниципального образования  \
# 0                                         4261000.00
# 1                                         3315000.00
# 2                                       587035000.00
# 3                                         1519000.00
# 4                                        12388000.00
#
#   Финансирование из внебюджетных источников  Активный  Действия с объектом  \
# 0                                      0.00         Y        строительство
# 1                                      0.00         Y        строительство
# 2                              129396500.00         Y        строительство
# 3                                      0.00         Y        строительство
# 4                                      0.00         Y        строительство
#
#    Общий объём финансирования. Проверка  sport_bool Есть виды спорта  \
# 0                          147105000.00       False                Y
# 1                           83829000.00       False                Y
# 2                          814724600.00       False                Y
# 3                          212165000.00       False                Y
# 4                          143946000.00        True                Y
#
#                                             Описание  \
# 0  крытый плавательный бассейн « садко » сдюсшор ...
# 1  спортивный зал для мини-футбол отдельно стоящи...
# 2  ледовый дворец спорт ледовый дворец спорт в го...
# 3  спортивный центр с плавательный бассейн спорти...
# 4  спортивный центр с универсальный игровой зал о...
#
#                                        Виды спорта 2
# 0              общая физическая подготовка, плавание
# 1                                футбол, мини-футбол
# 2  шахматы, хореография, фигурное катание, плаван...
# 3  общая физическая подготовка, игровые виды спор...
# 4  баскетбол, настольный теннис, теннис, игровые ...
#
# [5 rows x 24 columns]

# %%
# Для удобства уберем двоеточие в конце названий колонок и сразу перееименуем колону с оьемом финансирования в нужный нам формат

raw_columns_list = list(raw_data.columns.values)
raw_columns_list[0:5]
# Out:
# ['id:',
#  'Название:',
#  'Название (in english):',
#  'Активный:',
#  'Краткое описание:']

# %%
raw_columns_list = [c.replace(':', '') for c in raw_columns_list]
raw_columns_list = [c.replace('Общий объём финансирования', 'Общий объём финансирования (руб.)') for c in raw_columns_list]

raw_columns_list[0:5]
# Out:
# ['id', 'Название', 'Название (in english)', 'Активный', 'Краткое описание']

# %%
raw_data.columns = raw_columns_list

# %%
# Много строчек. Все ли нам нужны? найдем те что нам точно нужны . посмотрим списком 
raw_data.columns.to_list()
# Out:
# ['id',
#  'Название',
#  'Название (in english)',
#  'Активный',
#  'Краткое описание',
#  'Детальное описание',
#  'Краткое описание (in english)',
#  'Детальное описание (in english)',
#  'МО',
#  'Субъект федерации',
#  'Значимость',
#  'Населённый пункт',
#  'Населённый пункт (in english)',
#  'Адрес',
#  'Адрес (in english)',
#  'ОКТМО',
#  'ФЦП (федеральная целевая программа)',
#  'Действия с объектом',
#  'Дата начала строительства / реконструкции',
#  'Дата завершения строительства / реконструкции',
#  'Общий объём финансирования (руб.)',
#  'Финансирование из федерального бюджета',
#  'Финансирование из федерального бюджета (из них освоено)',
#  'Финансирование из бюджета субъекта федерации',
#  'Финансирование из бюджета субъекта федерации (из них освоено)',
#  'Финансирование из бюджета муниципального образования',
#  'Финансирование из бюджета муниципального образования (из них освоено)',
#  'Финансирование из внебюджетных источников',
#  'Финансирование из внебюджетных источников (из них освоено)',
#  'Ключевой или нет?',
#  'Курирующий орган',
#  'Курирующий орган (in english)',
#  'Адрес курирующего органа',
#  'Адрес курирующего органа (in english)',
#  'Телефон курирующего органа',
#  'Контактный телефон объекта',
#  'Режим работы Пн.-Пт.',
#  'Режим работы Сб.',
#  'Режим работы Вс.',
#  'Площадь',
#  'E-mail',
#  'URL сайта',
#  'Внесён в реестр?',
#  'Тип спортивного комплекса',
#  'Какие соревнования проводятся?',
#  'Виды спорта',
#  'Яндекс координата объекта X',
#  'Яндекс координата объекта Y',
#  'Маштаб Яндекс-карты',
#  'Яндекс координата центра X',
#  'Яндекс координата центра Y',
#  'Мини координата X',
#  'Мини координата Y',
#  'Генеральный план',
#  'Дополнительные планы',
#  'Фото',
#  'URL фото галереи объекта',
#  'Видео',
#  'Панорамы',
#  'Web-трансляции',
#  'Прочие материалы']

# %%
# Какие минимальные требования к нашему датасету?
# Исходя из той информации которую нам нужно получить нужна информация в текущих столбцах

columns_min =['Название', 'Адрес', 'Общий объём финансирования (руб.)', 'Виды спорта', 
              'Субъект федерации','Тип спортивного комплекса'
              #  емайл пишем с оговоркой, несмотря на обязательность очень обидно будет удалять незаполненнные
              ,'E-mail']

# %%
# так как колонок очень много попробуем дополнить лист минимальных колонок теми которые нам пригодятся.

need_columns_extended = columns_min + [
                            'Населённый пункт',
                            'Краткое описание',
                            'Детальное описание',
                            'Дата начала строительства / реконструкции',
                            'Дата завершения строительства / реконструкции',
                            'URL сайта',
                            'Финансирование из федерального бюджета',
                            'Финансирование из бюджета субъекта федерации',
                            'Финансирование из бюджета муниципального образования',
                            'Финансирование из внебюджетных источников',
                            'Активный',
                            'Действия с объектом'
                             ]

# %%
raw_data = raw_data[need_columns_extended]
raw_data.head()
# Out:
#                                           Название  \
# 0      Крытый плавательный бассейн «Садко» СДЮСШОР
# 1                  Спортивный зал для мини-футбола
# 2                            Ледовый дворец спорта
# 3        Спортивный центр с плавательным бассейном
# 4  Спортивный центр с универсальным игровым залом
#
#                                                Адрес  \
# 0  Ханты-Мансийский автономный округ, г. Советски...
# 1  Ханты-Мансийский автономный округ, г. Лангепас...
# 2  Ханты - Мансийский автономный округ, г. Сургут...
# 3  Ханты-Мансийский автономный округ, пос. Лыхма,...
# 4  Ханты-Мансийский автономный округ-Югра, г. Лан...
#
#    Общий объём финансирования (руб.)  \
# 0                       147105000.00
# 1                        83829000.00
# 2                       814724600.00
# 3                       212165000.00
# 4                       143946000.00
#
#                                          Виды спорта    Субъект федерации  \
# 0                                           плавание  Ханты-Мансийский АО
# 1  игровые виды спорта (разное), мини-футбол, общ...  Ханты-Мансийский АО
# 2  аквааэробика, греко-римская борьба, общая физи...  Ханты-Мансийский АО
# 3                             аквааэробика, плавание  Ханты-Мансийский АО
# 4  баскетбол, бодибилдинг, волейбол, настольный т...  Ханты-Мансийский АО
#
#                  Тип спортивного комплекса                 E-mail  \
# 0                                  бассейн          ukmps@mail.ru
# 1                           зал спортивный                    NaN
# 2                            арена ледовая        lds2011@list.ru
# 3  многофункциональный спортивный комплекс  NurtdinovRA@admbel.ru
# 4  многофункциональный спортивный комплекс                    NaN
#
#   Населённый пункт                                   Краткое описание  \
# 0     г. Советский  МБОУ ДОД СДЮСШОР г. Советский единственное учр...
# 1      г. Лангепас  Отдельно стоящее здание, расположено на обособ...
# 2        г. Сургут  Ледовый Дворец спорта в городе Сургуте открыт ...
# 3       пос. Лыхма  Спортивный центр с плавательным бассейном в п....
# 4      г. Лангепас  Отдельно стоящее здание, расположено на обособ...
#
#                                   Детальное описание  \
# 0  Общая площадь здания «Крытого плавательного ба...
# 1  Здание кирпичное, бетонное, блоки «Сэндвичи». ...
# 2  Общая площадь объекта составляет 21 247 м2. Пе...
# 3  Общая площадь объекта составляет 2111 м2. Пере...
# 4  Общая площадь объекта составляет 3092,8 м2. Пе...
#
#   Дата начала строительства / реконструкции  \
# 0                                2006-12-01
# 1                                2007-06-01
# 2                                2008-06-01
# 3                                2006-12-15
# 4                                2008-01-14
#
#   Дата завершения строительства / реконструкции URL сайта  \
# 0                                    2008-12-31       NaN
# 1                                    2009-12-30       NaN
# 2                                    2011-11-05       NaN
# 3                                    2009-12-24       NaN
# 4                                    2011-12-30       NaN
#
#    Финансирование из федерального бюджета  \
# 0                             10000000.00
# 1                             17500000.00
# 2                             90000000.00
# 3                             60000000.00
# 4                             17500000.00
#
#    Финансирование из бюджета субъекта федерации  \
# 0                                  132844000.00
# 1                                   63014000.00
# 2                                    8293100.00
# 3                                  150646000.00
# 4                                  114058000.00
#
#    Финансирование из бюджета муниципального образования  \
# 0                                         4261000.00
# 1                                         3315000.00
# 2                                       587035000.00
# 3                                         1519000.00
# 4                                        12388000.00
#
#    Финансирование из внебюджетных источников Активный Действия с объектом
# 0                                       0.00        Y       строительство
# 1                                       0.00        Y       строительство
# 2                               129396500.00        Y       строительство
# 3                                       0.00        Y       строительство
# 4                                       0.00        Y       строительство

# %%
# 'Дата начала строительства / реконструкции' и 'Дата начала строительства / реконструкции' 
# вероятно потребуется перевести в формат даты.
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 929 entries, 0 to 928
# Data columns (total 19 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Название                                              928 non-null    object
#  1   Адрес                                                 928 non-null    object
#  2   Общий объём финансирования (руб.)                     928 non-null    float64
#  3   Виды спорта                                           794 non-null    object
#  4   Субъект федерации                                     928 non-null    object
#  5   Тип спортивного комплекса                             925 non-null    object
#  6   E-mail                                                460 non-null    object
#  7   Населённый пункт                                      928 non-null    object
#  8   Краткое описание                                      762 non-null    object
#  9   Детальное описание                                    641 non-null    object
#  10  Дата начала строительства / реконструкции             705 non-null    object
#  11  Дата завершения строительства / реконструкции         830 non-null    object
#  12  URL сайта                                             88 non-null     object
#  13  Финансирование из федерального бюджета                928 non-null    float64
#  14  Финансирование из бюджета субъекта федерации          928 non-null    float64
#  15  Финансирование из бюджета муниципального образования  928 non-null    float64
#  16  Финансирование из внебюджетных источников             928 non-null    float64
#  17  Активный                                              928 non-null    object
#  18  Действия с объектом                                   928 non-null    object
# dtypes: float64(5), object(14)
# memory usage: 138.0+ KB

# %% [markdown]
# ### Проверка наполноту адекватность
# <a name="100."></a>
# #### Название
# <a name="11."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
print(raw_data['Название'].value_counts())

raw_data[raw_data['Название'].isna()]
# Out:
# Физкультурно-оздоровительный комплекс                72
# ДЮСШ                                                 19
# Спортивный комплекс                                  15
# Плавательный бассейн                                 14
# Футбольное поле с искусственным покрытием            14
#                                                      ..
# Плавательный бассейн «Аквамарин» ДЮСШ «Нефтяник»      1
# Бассейн СОШ № 11                                      1
# Горнолыжная база «Морозная»                           1
# ФОК с плавательным бассейном                          1
# Региональный центр-СДЮСШОР по зимним видам спорта     1
# Name: Название, Length: 646, dtype: int64
#     Название Адрес  Общий объём финансирования (руб.) Виды спорта  \
# 928      NaN   NaN                                nan         NaN
#
#     Субъект федерации Тип спортивного комплекса E-mail Населённый пункт  \
# 928               NaN                       NaN    NaN              NaN
#
#     Краткое описание Детальное описание  \
# 928              NaN                NaN
#
#     Дата начала строительства / реконструкции  \
# 928                                       NaN
#
#     Дата завершения строительства / реконструкции URL сайта  \
# 928                                           NaN       NaN
#
#      Финансирование из федерального бюджета  \
# 928                                     nan
#
#      Финансирование из бюджета субъекта федерации  \
# 928                                           nan
#
#      Финансирование из бюджета муниципального образования  \
# 928                                                nan
#
#      Финансирование из внебюджетных источников Активный Действия с объектом
# 928                                        nan      NaN                 NaN

# %%
#всего один и вся строка пустая - удалим

raw_data  =  raw_data.dropna(subset=['Название'])
raw_data[raw_data['Название'].isna()]
# Out:
# Empty DataFrame
# Columns: [Название, Адрес, Общий объём финансирования (руб.), Виды спорта, Субъект федерации, Тип спортивного комплекса, E-mail, Населённый пункт, Краткое описание, Детальное описание, Дата начала строительства / реконструкции, Дата завершения строительства / реконструкции, URL сайта, Финансирование из федерального бюджета, Финансирование из бюджета субъекта федерации, Финансирование из бюджета муниципального образования, Финансирование из внебюджетных источников, Активный, Действия с объектом]
# Index: []

# %% [markdown]
# #### Активный
# <a name="12."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
# интересно что застолбец активный и нужны ли нам неактивные обьекты и сколько их
raw_data['Активный'].value_counts()
# Большенство активных. Посмотри на неактивных
# Out:
# Y    847
# N     81
# Name: Активный, dtype: int64

# %%
table_active =raw_data.pivot_table(index=
    'Субъект федерации', columns='Активный',values = 'Адрес',  aggfunc='count', fill_value = 0).reset_index()

table_active['total'] =  table_active['N'] + table_active['Y']
table_active['N'] = table_active['N']/table_active['total'] * 100
table_active['Y'] = table_active['Y']/table_active['total'] * 100
table_active.head()
# Out:
# Активный      Субъект федерации          N          Y  total
# 0                Алтайский край      37.50      62.50      8
# 1              Амурская область      40.00      60.00      5
# 2         Архангельская область      16.67      83.33      6
# 3          Астраханская область       0.00     100.00     12
# 4          Белгородская область       0.00     100.00     14

# %%
# Визуализируем
sns.set(style="whitegrid")
plt.figure(figsize = (5,10)) 
data = table_active[table_active['N'] > 0].sort_values(by = 'N' , ascending = False)
sns.barplot(y='Субъект федерации', x='N', data=data, palette="tab20", linewidth=2.5)
plt.title('Активность обьектов по субъектам федерации', fontsize=15)
plt.ylabel("Субъекты федерации")
plt.xlabel("Количество")
plt.show()

# %% [markdown]
# В Крыму и Севастополе такие все. Видимо они еще не построились и только в процессе. Посмотрим процент недостроенных среди них.

# %%
#кажется они по времени могу быть не достроены
raw_data[raw_data['Активный'] == 'N'][columns_min + ['Дата завершения строительства / реконструкции','Действия с объектом','Финансирование из федерального бюджета',
                            'Финансирование из бюджета субъекта федерации',
                            'Финансирование из бюджета муниципального образования',
                            'Финансирование из внебюджетных источников']].head()
# Out:
#                                               Название  \
# 825     Футбольное поле с искусственным покрытием ДЮСШ
# 845                    ГУДО ТО ДЮСШ «Академия футбола»
# 846              Физкультурно-оздоровительный комплекс
# 847                        Крытый плавательный бассейн
# 848  МБУ Физкультурно-оздоровительный комплекс «Десна»
#
#                                                  Адрес  \
# 825  Воронежская область, пос. Стрелица, ул. Космон...
# 845  Тульская область, Ленинский район, пос. Обидим...
# 846  Веневский район, г. Венев, мкр. Южный, ул. Стр...
# 847  Владимирская область, Суздальский район, с. До...
# 848    Смоленская область, г. Десногорск, 2 микрорайон
#
#      Общий объём финансирования (руб.)                         Виды спорта  \
# 825                        23530000.00  мини-футбол, русская лапта, футбол
# 845                               0.00                              футбол
# 846                               0.00                                 NaN
# 847                               0.00                            плавание
# 848                               0.00                                 NaN
#
#         Субъект федерации                Тип спортивного комплекса  \
# 825   Воронежская область                         футбольное поле
# 845      Тульская область                                      NaN
# 846      Тульская область  многофункциональный спортивный комплекс
# 847  Владимирская область                                  бассейн
# 848    Смоленская область  многофункциональный спортивный комплекс
#
#                          E-mail Дата завершения строительства / реконструкции  \
# 825  semilukskayadyussh@mail.ru                                    01.05.2014
# 845                         NaN                                           NaN
# 846                         NaN                                           NaN
# 847                         NaN                                           NaN
# 848                         NaN                                           NaN
#
#     Действия с объектом  Финансирование из федерального бюджета  \
# 825       строительство                              8421000.00
# 845              другое                                    0.00
# 846       строительство                                    0.00
# 847       строительство                                    0.00
# 848       строительство                                    0.00
#
#      Финансирование из бюджета субъекта федерации  \
# 825                                   15000000.00
# 845                                          0.00
# 846                                          0.00
# 847                                          0.00
# 848                                          0.00
#
#      Финансирование из бюджета муниципального образования  \
# 825                                          109000.00
# 845                                               0.00
# 846                                               0.00
# 847                                               0.00
# 848                                               0.00
#
#      Финансирование из внебюджетных источников
# 825                                       0.00
# 845                                       0.00
# 846                                       0.00
# 847                                       0.00
# 848                                       0.00

# %%
# сколько без информации о неактивных?

print(len(raw_data[(raw_data['Активный'] == 'N') &(raw_data[
    'Дата завершения строительства / реконструкции'].isna())]))
# Out:
# 80

# %%
# сколько без информации об активных?

print(len(raw_data[(raw_data['Активный'] == 'N') &(raw_data[
    'Общий объём финансирования (руб.)']  == 0.00 )]))
# Out:
# 80

# %%
# сколько без информации об активных?

print(len(raw_data[(raw_data['Активный'] == 'Y') &(raw_data[
    'Дата завершения строительства / реконструкции'].isna() == False)]))

# к сожалению есть и такие  хорошо что только 2%
# вероятней всего дату окончания не обновили в регистре и она значится пустой
# Out:
# 829

# %%
raw_data[(raw_data['Активный'] == 'Y') &(raw_data[
    'Дата завершения строительства / реконструкции'].isna())][columns_min + ['Дата завершения строительства / реконструкции','Действия с объектом','Финансирование из федерального бюджета',
                            'Финансирование из бюджета субъекта федерации',
                            'Финансирование из бюджета муниципального образования',
                            'Финансирование из внебюджетных источников']].head()
# Out:
#                                               Название  \
# 311        ФГУП Учебно-тренировочный центр «Новогорск»
# 312  ФГБУ Тренировочный центр сборных команд России...
# 314  Федеральный тренировочный центр «Парамоново» (...
# 315  ФГУП Республиканская учебно-тренировочная база...
# 317  Антидопинговый центр на базе ФГБУ «Федеральный...
#
#                                                  Адрес  \
# 311  Московская область, г. Химки, мкр. Новогорск, ...
# 312                 Московская область, дер. Агафониха
# 314                Московская область, пос. Парамоново
# 315       Тульская область, г. Алексин, ул. Чехова, 21
# 317          г. Москва, пер. Елизаветинский, 10, стр.1
#
#      Общий объём финансирования (руб.)  \
# 311                      7305398700.00
# 312                      4665147200.00
# 314                      3329838200.00
# 315                      1619267200.00
# 317                      1038306000.00
#
#                                            Виды спорта   Субъект федерации  \
# 311  баскетбол, волейбол, гандбол, дзюдо, кёрлинг, ...  Московская область
# 312  бадминтон, водное поло, настольный теннис, пла...  Московская область
# 314  баскетбол, бобслей, волейбол, мини-футбол, сан...  Московская область
# 315  армспорт (армрестлинг), баскетбол на колясках,...    Тульская область
# 317                                                NaN              Москва
#
#                    Тип спортивного комплекса                 E-mail  \
# 311  многофункциональный спортивный комплекс                    NaN
# 312  многофункциональный спортивный комплекс  ozero-krugloe@mail.ru
# 314  многофункциональный спортивный комплекс                    NaN
# 315  многофункциональный спортивный комплекс                    NaN
# 317  многофункциональный спортивный комплекс                    NaN
#
#     Дата завершения строительства / реконструкции Действия с объектом  \
# 311                                           NaN       строительство
# 312                                           NaN       строительство
# 314                                           NaN       строительство
# 315                                           NaN       строительство
# 317                                           NaN       строительство
#
#      Финансирование из федерального бюджета  \
# 311                           7305398700.00
# 312                           4665147200.00
# 314                           3329838200.00
# 315                           1619267200.00
# 317                           1038306000.00
#
#      Финансирование из бюджета субъекта федерации  \
# 311                                          0.00
# 312                                          0.00
# 314                                          0.00
# 315                                          0.00
# 317                                          0.00
#
#      Финансирование из бюджета муниципального образования  \
# 311                                               0.00
# 312                                               0.00
# 314                                               0.00
# 315                                               0.00
# 317                                               0.00
#
#      Финансирование из внебюджетных источников
# 311                                       0.00
# 312                                       0.00
# 314                                       0.00
# 315                                       0.00
# 317                                       0.00

# %%
# сколько без информации об активных?

print(len(raw_data[(raw_data['Активный'] == 'Y') &(raw_data[
    'Общий объём финансирования (руб.)']  == 0.00 )]))

print(len(raw_data[(raw_data['Активный'] == 'Y') &(raw_data[
    'Дата завершения строительства / реконструкции'].isna())]))

# к сожалению есть и такие
# Out:
# 11
# 18

# %%
# удалим 80 из 81 неактивных кейса в них в них нет информации. об окончании строитестьтва и Общий объём финансирования (руб.)

raw_data = raw_data[(raw_data['Активный'] == 'Y') | (raw_data[
    'Общий объём финансирования (руб.)']  != 0.00 )]

print(len(raw_data[(raw_data['Активный'] == 'N') &(raw_data[
    'Общий объём финансирования (руб.)']  == 0.00 )]))
# Out:
# 0

# %% [markdown]
# #### Адрес
# <a name="13."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
raw_data.loc[:,['Адрес','Субъект федерации', 'Населённый пункт']].head()
# Out:
#                                                Адрес    Субъект федерации  \
# 0  Ханты-Мансийский автономный округ, г. Советски...  Ханты-Мансийский АО
# 1  Ханты-Мансийский автономный округ, г. Лангепас...  Ханты-Мансийский АО
# 2  Ханты - Мансийский автономный округ, г. Сургут...  Ханты-Мансийский АО
# 3  Ханты-Мансийский автономный округ, пос. Лыхма,...  Ханты-Мансийский АО
# 4  Ханты-Мансийский автономный округ-Югра, г. Лан...  Ханты-Мансийский АО
#
#   Населённый пункт
# 0     г. Советский
# 1      г. Лангепас
# 2        г. Сургут
# 3       пос. Лыхма
# 4      г. Лангепас

# %%
raw_data.loc[1,['Адрес']].values
# Out:
# array(['Ханты-Мансийский автономный округ, г. Лангепас, ул. Солнечная, 23/б'],
#       dtype=object)

# %%
# смотрим что нет пропусков

print('Адрес:',len(raw_data[raw_data['Адрес'].isna()]),
      '\nСубъект федерации:', len(raw_data[raw_data['Субъект федерации'].isna()]),
      '\nНаселённый пункт:', len(raw_data[raw_data['Населённый пункт'].isna()]))
# Out:
# Адрес: 0
# Субъект федерации: 0
# Населённый пункт: 0

# %%
# т.к стринг попробуем и так проверить

print('Адрес:',len(raw_data[raw_data['Адрес'] == '']),
      '\nСубъект федерации:', len(raw_data[raw_data['Субъект федерации'] == '']),
      '\nНаселённый пункт:', len(raw_data[raw_data['Населённый пункт'] == '']))
# Out:
# Адрес: 0
# Субъект федерации: 0
# Населённый пункт: 0

# %%
# посмотрим что нет больших перекосов по субъектам и населеным пунктам (пример все из одного региона и города)

raw_data['Субъект федерации'].value_counts().head(10)
# Out:
# Республика Мордовия     41
# Воронежская область     24
# Республика Чувашия      22
# Пензенская область      22
# Краснодарский край      21
# Пермский край           21
# Омская область          20
# Республика Татарстан    19
# Оренбургская область    19
# Тамбовская область      18
# Name: Субъект федерации, dtype: int64

# %%
raw_data['Населённый пункт'].value_counts().head(10)
# Out:
# г. Саранск        12
# г. Тамбов          8
# г. Пенза           7
# г. Ижевск          7
# г. Новосибирск     7
# г. Москва          7
# г. Омск            7
# г. Уфа             6
# г. Брянск          6
# г. Йошкар-Ола      6
# Name: Населённый пункт, dtype: int64

# %%
# Многовато мордовии.Вроде не критично, по посмотрим поближе. возможно связанно с чемпионатом по футболу в 2008
raw_data['Год завершения строительства / реконструкции'] = raw_data[
    'Дата завершения строительства / реконструкции'].str.split('.', expand = True)[2].astype('float')

raw_data['total'] = 1
table_mordovia = raw_data[(raw_data['Субъект федерации']  == 'Республика Мордовия')].groupby([
    'Год завершения строительства / реконструкции'])['total'].sum().reset_index()

# %%
# Визуализируем
sns.set(style="whitegrid")
plt.figure(figsize = (10,5)) 
data = table_mordovia
sns.barplot(x='Год завершения строительства / реконструкции', y= 'total', data=data, palette="tab20", linewidth=2.5)
plt.title('Информация о завершении строительства / реконструкции в Мордовии по годам', fontsize=15)
plt.xlabel('Год завершения строительства / реконструкции ')
plt.ylabel("Количество")
plt.show()

# %%
# в 2010 было завершено много обьектов

# %% [markdown]
# #### E-mail
# <a name="14."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
# Сколько нет?
print("Нет емайлов:", len(raw_data[raw_data['E-mail'].isna()]))
# Out:
# Нет емайлов: 388

# %%
raw_data['E-mail'].value_counts().head()
# Out:
# sportstroy@mail.ru               19
# tehnadzor.minsportrme@mail.ru    15
# aleksey.karelin1985@mail.ru      12
# sport@admin.smolensk.ru          11
# mmpsvg@mail.ru                   10
# Name: E-mail, dtype: int64

# %%
# Дубликаы вероятно обозначают что это 'сети'. В нашем случае однин регион. Давайте провермм
raw_data[raw_data['E-mail'] == 'sportstroy@mail.ru'].head()

# Все верно.
# Out:
#                                              Название  \
# 17  Футбольное поле с искусственным покрытием ДЮСШ...
# 18                        Спортивная школа по футболу
# 19                 Спортивно-оздоровительный комплекс
# 20          Футбольное поле с искусственным покрытием
# 21     Футбольное поле с искусственным покрытием ДЮСШ
#
#                                                 Адрес  \
# 17     Краснодарский край, г. Абинск, ул. Советов, 35
# 18  Краснодарский край, г. Ейск, ул. Портовая Алле...
# 19   Краснодарский край, ст. Кущёвская, ул. Ленина,16
# 20  Краснодарский край, г. Лабинск, ул. Лермонтова...
# 21                  Краснодарский край, ст. Северская
#
#     Общий объём финансирования (руб.)  \
# 17                        19421000.00
# 18                        19440000.00
# 19                       218576000.00
# 20                        17800000.00
# 21                        20652600.00
#
#                                           Виды спорта   Субъект федерации  \
# 17                                             футбол  Краснодарский край
# 18                                             футбол  Краснодарский край
# 19  бадминтон, баскетбол, волейбол, вольная борьба...  Краснодарский край
# 20                                             футбол  Краснодарский край
# 21                                             футбол  Краснодарский край
#
#                   Тип спортивного комплекса              E-mail  \
# 17                         футбольное поле   sportstroy@mail.ru
# 18                                  стадион  sportstroy@mail.ru
# 19  многофункциональный спортивный комплекс  sportstroy@mail.ru
# 20                         футбольное поле   sportstroy@mail.ru
# 21                                  стадион  sportstroy@mail.ru
#
#    Населённый пункт                                   Краткое описание  \
# 17        г. Абинск  В 2012 году проводился капитальный ремонт футб...
# 18          г. Ейск  Проводился капительный ремонт поля в 2010 году...
# 19    ст. Кущёвская  Строительство спортивно-оздоровительного компл...
# 20       г. Лабинск  Позволило увеличить площадь плоскостных спорти...
# 21    ст. Северская  Позволило увеличить площадь плоскостных спорти...
#
#                                    Детальное описание  ...  \
# 17  Строительство велось с использованием типовых ...  ...
# 18                                    Типовой проект.  ...
# 19  В зале имеются следующие спортивные помещения:...  ...
# 20  В 2009 году был произведен капитальный ремонт ...  ...
# 21                    Применялись типовые технологии.  ...
#
#    Дата завершения строительства / реконструкции URL сайта  \
# 17                                    01.12.2012       NaN
# 18                                    14.09.2011       NaN
# 19                                    26.12.2011       NaN
# 20                                    29.12.2009       NaN
# 21                                    01.12.2011       NaN
#
#    Финансирование из федерального бюджета  \
# 17                             8421000.00
# 18                             8440000.00
# 19                            17500000.00
# 20                             8450000.00
# 21                             8421000.00
#
#     Финансирование из бюджета субъекта федерации  \
# 17                                    8500000.00
# 18                                    8500000.00
# 19                                  201076000.00
# 20                                    8500000.00
# 21                                    8500000.00
#
#     Финансирование из бюджета муниципального образования  \
# 17                                         2500000.00
# 18                                         2500000.00
# 19                                               0.00
# 20                                          850000.00
# 21                                         3731600.00
#
#     Финансирование из внебюджетных источников  Активный Действия с объектом  \
# 17                                       0.00         Y       реконструкция
# 18                                       0.00         Y       реконструкция
# 19                                       0.00         Y       реконструкция
# 20                                       0.00         Y       реконструкция
# 21                                       0.00         Y       реконструкция
#
#    Год завершения строительства / реконструкции  total
# 17                                      2012.00      1
# 18                                      2011.00      1
# 19                                      2011.00      1
# 20                                      2009.00      1
# 21                                      2011.00      1
#
# [5 rows x 21 columns]

# %%
# проверим емайлы на адекватность и поправим
def to_validate_email(base):
    email = base['E-mail']
    # если не пустой
    if (pd.isnull(email) == False):
        # проверяем на валидность
        if ((validate_email(email) == False) 
        or (pd.isnull(re.fullmatch(r'[a-zA-Z0-9\.\-_+]+@[\w\.-]+\.\w+', email)) == True)):
            # разделяем 
            email_parts = email.split('@')
            # если надо добавдяем в конец .ru (у нас правительственная база, другие окончания не должны быть)
            if email_parts[-1].find('.') == -1:
                # сделаем исключение (есть в базе)
                if email_parts[-1] == 'gmail':
                    email_parts[-1] = email_parts[-1] + '.com'
                else:
                    email_parts[-1] = email_parts[-1] + '.ru'
            # печатаем что поправили
            print(email, email_parts)
            
            # собираем назад емайл 
            email = email_parts[0] + "@"
            for p in email_parts[1:]:
                email = email + p    
    return email

raw_data['E-mail_new'] = raw_data.apply(to_validate_email, axis=1)
# Out:
# NurtdinovRA@admbel ['NurtdinovRA', 'admbel.ru']
# zenit-volgograd@mail ['zenit-volgograd', 'mail.ru']
# zenit-volgograd@mail ['zenit-volgograd', 'mail.ru']
# maodush5@mail ['maodush5', 'mail.ru']
# skap2009@yandex ['skap2009', 'yandex.ru']
# skap2009@yandex ['skap2009', 'yandex.ru']
# golubovichv@mail ['golubovichv', 'mail.ru']
# skap2009@yandex ['skap2009', 'yandex.ru']
# bibiksarovaog@gmail ['bibiksarovaog', 'gmail.com']
# M_Chernov@volganet ['M_Chernov', 'volganet.ru']
# afanasyev@gov-murman ['afanasyev', 'gov-murman.ru']
# afanasyev@gov-murman ['afanasyev', 'gov-murman.ru']
# sportotdel_vbg@mail ['sportotdel_vbg', 'mail.ru']

# %%
# Ну к сожалению тут мы не сможем найти все мейлы недостающие. 
# Хоть и попробуем если есть сайт 
raw_data[raw_data['E-mail_new'].isna() & (raw_data['URL сайта'].isna() == False)].head()
# Out:
#                                               Название  \
# 294            Футбольное поле СДЮСШОР стадион «Знамя»
# 311        ФГУП Учебно-тренировочный центр «Новогорск»
# 392                                     ФОК «Савелово»
# 400                                     Крытый бассейн
# 509  СДЮШОР по легкой атлетике и дзюдо Спортивно-оз...
#
#                                                  Адрес  \
# 294  Удмуртская Республика, г. Воткинск, ул. Орджон...
# 311  Московская область, г. Химки, мкр. Новогорск, ...
# 392        Тверская область, г. Кимры, ул. Туполева, 9
# 400       Тверская область, г. Торжок, ул. Энгельса, 2
# 509  Брянская область, г. Брянск, ул. 2-я Мичуринск...
#
#      Общий объём финансирования (руб.)  \
# 294                        20921000.00
# 311                      7305398700.00
# 392                        30760000.00
# 400                       103173000.00
# 509                       311359000.00
#
#                                            Виды спорта      Субъект федерации  \
# 294                                             футбол  Удмуртская Республика
# 311  баскетбол, волейбол, гандбол, дзюдо, кёрлинг, ...     Московская область
# 392  бадминтон, баскетбол, лёгкая атлетика, мини-фу...       Тверская область
# 400  водное поло, плавание, синхронное плавание, сп...       Тверская область
# 509  баскетбол, волейбол, гандбол, дзюдо, лёгкая ат...       Брянская область
#
#                    Тип спортивного комплекса E-mail Населённый пункт  \
# 294                         футбольное поле     NaN      г. Воткинск
# 311  многофункциональный спортивный комплекс    NaN         г. Химки
# 392  многофункциональный спортивный комплекс    NaN         г. Кимры
# 400                                  бассейн    NaN        г. Торжок
# 509  многофункциональный спортивный комплекс    NaN        г. Брянск
#
#                                       Краткое описание  \
# 294  Благодаря реконструкции стадиона «Знамя» на об...
# 311  Учебно-тренировочный центр «Новогорск» являетс...
# 392  С вводом в эксплуатацию данного объекта показа...
# 400  В г. Торжке  – крупном населенном пункте Тверс...
# 509  Спортивно-оздоровительный комплекс «Брянск» пр...
#
#                                     Детальное описание  ...  \
# 294  Используется современное искусственное футболь...  ...
# 311                                                NaN  ...
# 392  Размер зала - 42х24 м, площадь здания манежа -...  ...
# 400  Общая площадь здания бассейна составляет 3370,...  ...
# 509  Здание спортивно-оздоровительного комплекса вы...  ...
#
#                          URL сайта Финансирование из федерального бюджета  \
# 294             votkinsk-znamya.ru                             8421000.00
# 311  http://www.novogorsksport.ru/                          7305398700.00
# 392         http://дюсш2-кимры.рф/                            17500000.00
# 400             dolphin-torzhok.ru                            27600000.00
# 509             gausok-brayansk.ru                            17500000.00
#
#     Финансирование из бюджета субъекта федерации  \
# 294                                  12500000.00
# 311                                         0.00
# 392                                   6630000.00
# 400                                  38473000.00
# 509                                 293859000.00
#
#      Финансирование из бюджета муниципального образования  \
# 294                                               0.00
# 311                                               0.00
# 392                                         6630000.00
# 400                                        37100000.00
# 509                                               0.00
#
#      Финансирование из внебюджетных источников  Активный  Действия с объектом  \
# 294                                       0.00         Y        строительство
# 311                                       0.00         Y        строительство
# 392                                       0.00         Y        строительство
# 400                                       0.00         Y        строительство
# 509                                       0.00         Y        строительство
#
#     Год завершения строительства / реконструкции total  E-mail_new
# 294                                      2012.00     1         NaN
# 311                                          nan     1         NaN
# 392                                      2011.00     1         NaN
# 400                                      2010.00     1         NaN
# 509                                      2010.00     1         NaN
#
# [5 rows x 22 columns]

# %%
# попробуем найти недостающие по юрл (где есть)

def find_first_email(url):
    # Существует ли сайт
    try:
        response = requests.get(url, headers=headers, allow_redirects=True)
    except:
        print(colored('Сайт не доступен:','red'), url)
        return

    page_text = ''
    # запрос
    if response.status_code == 200:
        page_text = response.text
        # ищем емайл на странице и валидируем
        emails = re.findall(r'[a-zA-Z0-9\.\-_+]+@[\w\.-]+\.\w+', page_text)
        #валидируем
        try:
            for e in emails:
                len_e = len(emails)
                if len_e == 0:
                    print('Запрос прошел успешно:', url , 'Емал НЕ найден')
                    return None
                if e.find('covid') != -1:
                    continue
                if (e.split('.')[-1] == 'jpg'):
                    len_e = len_e - 1
                    continue
                if validate_email(e):
                    email = e
                    break
            print(colored('Запрос прошел успешно:','green'), url, colored('Емал найден:','green'), email)
            return email
        except:
            print('Запрос прошел успешно:', url , 'Емал НЕ найден')
            return None
    else:
        print('Ошибка! Response code:', response.status_code,'URL:', url)

def find_in_base(base):
    email = base['E-mail_new']
    url = base['URL сайта']
    if (pd.isnull(email) & (pd.isnull(url) == False)):
        if (re.match(r'^https?://',url) == None):
            url = 'http://' + url
        return find_first_email(url)
    return email

# %%
raw_data['E-mail_new'] = raw_data.apply(find_in_base, axis=1)
# Out:
# Запрос прошел успешно: http://votkinsk-znamya.ru Емал найден: contact@votkinsk-znamya.ru
# Запрос прошел успешно: http://www.novogorsksport.ru/ Емал найден: info@novogorsksport.ru
# Запрос прошел успешно: http://дюсш2-кимры.рф/ Емал НЕ найден
# Сайт не доступен: http://dolphin-torzhok.ru
# Сайт не доступен: http://gausok-brayansk.ru
# Запрос прошел успешно: http://www.vgafk.ru Емал найден: academy@vgafk.ru
# Запрос прошел успешно: http://Dush3vilyuismaneje.umi.ru/adminzone Емал НЕ найден
# Сайт не доступен: http://sernovodsksport.ru/
# Запрос прошел успешно: http://dushmetallurg-tula.ru Емал найден: dyusshmetallurg@tularegion.org
# Запрос прошел успешно: http://www.cspsk.ru/ Емал НЕ найден
# Запрос прошел успешно: http://www.izhneftyanic.ru/ Емал НЕ найден

# %%
# Удалять строчки с пустыми емайлами рука не поднимается. Оставим так

print("E-mail пропущенные", len(raw_data[raw_data['E-mail_new'].isna()]))
raw_data = raw_data.rename(columns={'E-mail_new': 'E-mail','E-mail': 'E-mail_old'})
raw_data.head()
# Out:
# E-mail пропущенные 384
#                                           Название  \
# 0      Крытый плавательный бассейн «Садко» СДЮСШОР
# 1                  Спортивный зал для мини-футбола
# 2                            Ледовый дворец спорта
# 3        Спортивный центр с плавательным бассейном
# 4  Спортивный центр с универсальным игровым залом
#
#                                                Адрес  \
# 0  Ханты-Мансийский автономный округ, г. Советски...
# 1  Ханты-Мансийский автономный округ, г. Лангепас...
# 2  Ханты - Мансийский автономный округ, г. Сургут...
# 3  Ханты-Мансийский автономный округ, пос. Лыхма,...
# 4  Ханты-Мансийский автономный округ-Югра, г. Лан...
#
#    Общий объём финансирования (руб.)  \
# 0                       147105000.00
# 1                        83829000.00
# 2                       814724600.00
# 3                       212165000.00
# 4                       143946000.00
#
#                                          Виды спорта    Субъект федерации  \
# 0                                           плавание  Ханты-Мансийский АО
# 1  игровые виды спорта (разное), мини-футбол, общ...  Ханты-Мансийский АО
# 2  аквааэробика, греко-римская борьба, общая физи...  Ханты-Мансийский АО
# 3                             аквааэробика, плавание  Ханты-Мансийский АО
# 4  баскетбол, бодибилдинг, волейбол, настольный т...  Ханты-Мансийский АО
#
#                  Тип спортивного комплекса          E-mail_old  \
# 0                                  бассейн       ukmps@mail.ru
# 1                           зал спортивный                 NaN
# 2                            арена ледовая     lds2011@list.ru
# 3  многофункциональный спортивный комплекс  NurtdinovRA@admbel
# 4  многофункциональный спортивный комплекс                 NaN
#
#   Населённый пункт                                   Краткое описание  \
# 0     г. Советский  МБОУ ДОД СДЮСШОР г. Советский единственное учр...
# 1      г. Лангепас  Отдельно стоящее здание, расположено на обособ...
# 2        г. Сургут  Ледовый Дворец спорта в городе Сургуте открыт ...
# 3       пос. Лыхма  Спортивный центр с плавательным бассейном в п....
# 4      г. Лангепас  Отдельно стоящее здание, расположено на обособ...
#
#                                   Детальное описание  ... URL сайта  \
# 0  Общая площадь здания «Крытого плавательного ба...  ...       NaN
# 1  Здание кирпичное, бетонное, блоки «Сэндвичи». ...  ...       NaN
# 2  Общая площадь объекта составляет 21 247 м2. Пе...  ...       NaN
# 3  Общая площадь объекта составляет 2111 м2. Пере...  ...       NaN
# 4  Общая площадь объекта составляет 3092,8 м2. Пе...  ...       NaN
#
#   Финансирование из федерального бюджета  \
# 0                            10000000.00
# 1                            17500000.00
# 2                            90000000.00
# 3                            60000000.00
# 4                            17500000.00
#
#   Финансирование из бюджета субъекта федерации  \
# 0                                 132844000.00
# 1                                  63014000.00
# 2                                   8293100.00
# 3                                 150646000.00
# 4                                 114058000.00
#
#    Финансирование из бюджета муниципального образования  \
# 0                                         4261000.00
# 1                                         3315000.00
# 2                                       587035000.00
# 3                                         1519000.00
# 4                                        12388000.00
#
#    Финансирование из внебюджетных источников  Активный  Действия с объектом  \
# 0                                       0.00         Y        строительство
# 1                                       0.00         Y        строительство
# 2                               129396500.00         Y        строительство
# 3                                       0.00         Y        строительство
# 4                                       0.00         Y        строительство
#
#   Год завершения строительства / реконструкции total                 E-mail
# 0                                      2008.00     1          ukmps@mail.ru
# 1                                      2009.00     1                    NaN
# 2                                      2011.00     1        lds2011@list.ru
# 3                                      2009.00     1  NurtdinovRA@admbel.ru
# 4                                      2011.00     1                    NaN
#
# [5 rows x 22 columns]

# %%
# откинем лишние столбцы
raw_data = raw_data[need_columns_extended]

# %% [markdown]
# #### Общий объём финансирования (руб.)
# <a name="15."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
# посмотрим
raw_data.describe()
# Out:
#        Общий объём финансирования (руб.)  \
# count                             848.00
# mean                        190050033.25
# std                         584560436.51
# min                                 0.00
# 25%                          18481402.50
# 50%                          46305084.00
# 75%                         142524875.00
# max                        7897261400.00
#
#        Финансирование из федерального бюджета  \
# count                                  848.00
# mean                             119354980.91
# std                              484231172.98
# min                                      0.00
# 25%                                8450000.00
# 50%                               20000000.00
# 75%                               60000000.00
# max                             7305398700.00
#
#        Финансирование из бюджета субъекта федерации  \
# count                                        848.00
# mean                                    56182222.25
# std                                    203481872.72
# min                                            0.00
# 25%                                            0.00
# 50%                                      6471000.00
# 75%                                     37978050.00
# max                                   4111120200.00
#
#        Финансирование из бюджета муниципального образования  \
# count                                             848.00
# mean                                         13207937.32
# std                                         135723616.17
# min                                                 0.00
# 25%                                                 0.00
# 50%                                                 0.00
# 75%                                           2325000.00
# max                                        3777720200.00
#
#        Финансирование из внебюджетных источников
# count                                     848.00
# mean                                  1304892.77
# std                                  10172863.82
# min                                         0.00
# 25%                                         0.00
# 50%                                         0.00
# 75%                                         0.00
# max                                 141000000.00

# %%
#Есть нули. Предполагаю, что это не ноль рублей финансирования, на отсутивие информации.
print("Пропуски:",len(raw_data[raw_data['Общий объём финансирования (руб.)'] == 0.00])
,"+", len(raw_data[raw_data['Общий объём финансирования (руб.)'].isna()]))

display(raw_data[raw_data['Общий объём финансирования (руб.)'] == 0.00].head())
# Out:
# Пропуски: 11 + 0
#                                               Название  \
# 210                            Дворец спорта «Буртасы»
# 488                       Спортивный комплекс «Лидер»
# 701  Плавательный бассейн университета Республики Тыва
# 720                                ФГБОУ ВПО РГУФКСМиТ
# 728                               Плавательный бассейн
#
#                                                  Адрес  \
# 210  Пензенская область, г. Пенза, пр-т Строителей, 96
# 488  Челябинская область, г. Челябинск, ул. Копейск...
# 701      Республика Тыва, г. Кызыл, ул. Колхозная, 125
# 720                       г. Москва, бул. Сиреневый, 4
# 728    Рязанская область, г. Сасово, мкр. Северный, 60
#
#      Общий объём финансирования (руб.)  \
# 210                               0.00
# 488                               0.00
# 701                               0.00
# 720                               0.00
# 728                               0.00
#
#                                            Виды спорта    Субъект федерации  \
# 210  водное поло, плавание, прыжки в воду, спортивн...   Пензенская область
# 488                                             футбол  Челябинская область
# 701                                           плавание      Республика Тыва
# 720                                                NaN               Москва
# 728                                плавание, полиатлон    Рязанская область
#
#                    Тип спортивного комплекса                E-mail  \
# 210  многофункциональный спортивный комплекс                   NaN
# 488                         футбольное поле                    NaN
# 701                                  бассейн      sajzana@inbox.ru
# 720  многофункциональный спортивный комплекс                   NaN
# 728                                  бассейн  neptunsasovo@mail.ru
#
#     Населённый пункт                                   Краткое описание  \
# 210         г. Пенза  Создание условий для проведения физкультурно-о...
# 488     г. Челябинск  Спортивный комплекс расположен в отдаленном ра...
# 701         г. Кызыл  Бассейн построен  в удобном и доступном месте,...
# 720        г. Москва                                                NaN
# 728        г. Сасово  Организация и проведение спортивных и физкульт...
#
#                                     Детальное описание  \
# 210                                                NaN
# 488                                                NaN
# 701           Быстровозводимое каркасное строительство
# 720                                                NaN
# 728  Применение озонирующей установки «ОЗОН-80ПВ-ВБ...
#
#     Дата начала строительства / реконструкции  \
# 210                                04.07.2005
# 488                                01.07.2010
# 701                                02.02.2010
# 720                                       NaN
# 728                                10.05.2004
#
#     Дата завершения строительства / реконструкции URL сайта  \
# 210                                    19.10.2007       NaN
# 488                                    30.10.2011       NaN
# 701                                    30.11.2012       NaN
# 720                                    30.12.2015       NaN
# 728                                    14.09.2013       NaN
#
#      Финансирование из федерального бюджета  \
# 210                                    0.00
# 488                                    0.00
# 701                                    0.00
# 720                                    0.00
# 728                                    0.00
#
#      Финансирование из бюджета субъекта федерации  \
# 210                                          0.00
# 488                                          0.00
# 701                                          0.00
# 720                                          0.00
# 728                                          0.00
#
#      Финансирование из бюджета муниципального образования  \
# 210                                               0.00
# 488                                               0.00
# 701                                               0.00
# 720                                               0.00
# 728                                               0.00
#
#      Финансирование из внебюджетных источников Активный Действия с объектом
# 210                                       0.00        Y       строительство
# 488                                       0.00        Y       реконструкция
# 701                                       0.00        Y       строительство
# 720                                       0.00        Y       строительство
# 728                                       0.00        Y       строительство

# %%
raw_data[(raw_data['Общий объём финансирования (руб.)'] == 0.00) &
        ((raw_data['Финансирование из федерального бюджета'] != 0.00) |
         (raw_data['Финансирование из бюджета субъекта федерации'] != 0.00) |
         (raw_data['Финансирование из бюджета муниципального образования'] != 0.00) |
         (raw_data['Финансирование из внебюджетных источников'] != 0.00) 
        )].head()
#На осовании бюджетов не сможем также данные свести. Исключаем
# Out:
# Empty DataFrame
# Columns: [Название, Адрес, Общий объём финансирования (руб.), Виды спорта, Субъект федерации, Тип спортивного комплекса, E-mail, Населённый пункт, Краткое описание, Детальное описание, Дата начала строительства / реконструкции, Дата завершения строительства / реконструкции, URL сайта, Финансирование из федерального бюджета, Финансирование из бюджета субъекта федерации, Финансирование из бюджета муниципального образования, Финансирование из внебюджетных источников, Активный, Действия с объектом]
# Index: []

# %%
raw_data = raw_data[raw_data['Общий объём финансирования (руб.)'] != 0.00]
len(raw_data)
# Out:
# 837

# %%
# остальные сверим с отдельным финансированием, возможно в общем что-то не учтено

raw_data['Общий объём финансирования. Проверка'] = raw_data[
    'Финансирование из федерального бюджета'] + raw_data[
    'Финансирование из бюджета субъекта федерации'] + raw_data[
    'Финансирование из бюджета муниципального образования'] + raw_data[
    'Финансирование из внебюджетных источников']

# %%
raw_data[raw_data['Общий объём финансирования. Проверка'] != raw_data['Общий объём финансирования (руб.)']]

# Отлично, таких нет
# Out:
# Empty DataFrame
# Columns: [Название, Адрес, Общий объём финансирования (руб.), Виды спорта, Субъект федерации, Тип спортивного комплекса, E-mail, Населённый пункт, Краткое описание, Детальное описание, Дата начала строительства / реконструкции, Дата завершения строительства / реконструкции, URL сайта, Финансирование из федерального бюджета, Финансирование из бюджета субъекта федерации, Финансирование из бюджета муниципального образования, Финансирование из внебюджетных источников, Активный, Действия с объектом, Общий объём финансирования. Проверка]
# Index: []

# %%
# посмотрм на распределение
plt.figure(figsize = (12,5)) 
millions = round(raw_data['Общий объём финансирования (руб.)'] / 1000000,0)
millions.hist(bins = 100, facecolor='g',alpha=0.7, density=True)

# Визуализируем
sns.set(style="whitegrid")

data = raw_data
plt.xlim(0, 2000)
plt.title('Общий объём финансирования', fontsize=15)
plt.xlabel("миллионов рублей")
plt.ylabel("Плотность")
plt.grid(True)
plt.show()

# %%
millions.value_counts(normalize=True).head()
# Out:
#  8.00         0.05
# 18.00         0.05
# 20.00         0.03
# 40.00         0.02
# 19.00         0.02
# Name: Общий объём финансирования (руб.), dtype: float64

# %% [markdown]
# #### Тип спортивного комплекса
# <a name="16."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
#У нас он такой один. Найдем виды спорта тенис и посмотрим какой тип компликса у них
print("Пропуски" ,len(raw_data[raw_data['Тип спортивного комплекса'] == ''])
, "+ ", len(raw_data[raw_data['Тип спортивного комплекса'].isna()]))

display(raw_data[raw_data['Тип спортивного комплекса'].isna()].head())
# Out:
# Пропуски 0 +  1
#                    Название                         Адрес  \
# 804  Центр большого тенниса  Рязанская область, г. Рязань
#
#      Общий объём финансирования (руб.) Виды спорта  Субъект федерации  \
# 804                       300000000.00      теннис  Рязанская область
#
#     Тип спортивного комплекса E-mail Населённый пункт  \
# 804                       NaN    NaN        г. Рязань
#
#                                       Краткое описание Детальное описание  \
# 804  Академия большого тенниса в Рязани состоит из ...                NaN
#
#     Дата начала строительства / реконструкции  \
# 804                                       NaN
#
#     Дата завершения строительства / реконструкции URL сайта  \
# 804                                    31.08.2015       NaN
#
#      Финансирование из федерального бюджета  \
# 804                            300000000.00
#
#      Финансирование из бюджета субъекта федерации  \
# 804                                          0.00
#
#      Финансирование из бюджета муниципального образования  \
# 804                                               0.00
#
#      Финансирование из внебюджетных источников Активный Действия с объектом  \
# 804                                       0.00        Y       строительство
#
#      Общий объём финансирования. Проверка
# 804                          300000000.00

# %%
raw_data['sport_bool'] = raw_data['Виды спорта'].str.contains("теннис", na = ' ')
data = raw_data[raw_data['sport_bool'] == True]['Тип спортивного комплекса'].value_counts()

# %%
# Визуализируем
sns.set(style="whitegrid")
plt.figure(figsize = (7,5)) 

sns.barplot(y=data.index, x=data.values, palette="tab20", linewidth=2.5)
plt.title('Типы спортивного комплекса для активности Теннис', fontsize=15)
plt.xlabel("Количество")
plt.ylabel("Тип")
plt.show()


# Многофункциональнй комплекс нам не подходит - обозначим как спортивнй зал (2 по популярности ответ)

# %%
# Заполним fillna поскольку он у нас один и более детально не требуется
raw_data['Тип спортивного комплекса'] = raw_data['Тип спортивного комплекса'].fillna('зал спортивный')
display(raw_data[raw_data['Тип спортивного комплекса'].isna()].head())
# Out:
# Empty DataFrame
# Columns: [Название, Адрес, Общий объём финансирования (руб.), Виды спорта, Субъект федерации, Тип спортивного комплекса, E-mail, Населённый пункт, Краткое описание, Детальное описание, Дата начала строительства / реконструкции, Дата завершения строительства / реконструкции, URL сайта, Финансирование из федерального бюджета, Финансирование из бюджета субъекта федерации, Финансирование из бюджета муниципального образования, Финансирование из внебюджетных источников, Активный, Действия с объектом, Общий объём финансирования. Проверка, sport_bool]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# #### Виды спорта
# <a name="17."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
#Есть на
print("Пропуски" ,len(raw_data[raw_data['Виды спорта'] == ''])
, "+ ", len(raw_data[raw_data['Виды спорта'].isna()]))

display(raw_data[raw_data['Виды спорта'].isna()].head())
# Out:
# Пропуски 0 +  54
#                                       Название  \
# 54                     Многофункциональный зал
# 259      Физкультурно-оздоровительный комплекс
# 265  Физкультурно-спортивный центр «Локомотив»
# 270                                 ФОК «Атал»
# 271                           ФОК «Мариинский»
#
#                                                  Адрес  \
# 54   Хабаровский край, г. Комсомольск-на-Амуре, ул....
# 259                     Республика Чувашия, г. Алатырь
# 265                       Республика Чувашия, г. Канаш
# 270                    Республика Чувашия, с. Козловка
# 271            Республика Чувашия, г. Мариинский Посад
#
#      Общий объём финансирования (руб.) Виды спорта   Субъект федерации  \
# 54                         47800000.00         NaN    Хабаровский край
# 259                        17500000.00         NaN  Республика Чувашия
# 265                        38900000.00         NaN  Республика Чувашия
# 270                        60000000.00         NaN  Республика Чувашия
# 271                        60000000.00         NaN  Республика Чувашия
#
#                    Тип спортивного комплекса E-mail         Населённый пункт  \
# 54                            зал спортивный    NaN  г. Комсомольск-на-Амуре
# 259  многофункциональный спортивный комплекс    NaN               г. Алатырь
# 265  многофункциональный спортивный комплекс    NaN                 с. Канаш
# 270  многофункциональный спортивный комплекс    NaN              с. Козловка
# 271  многофункциональный спортивный комплекс    NaN      г. Мариинский Посад
#
#                                       Краткое описание  \
# 54   Предназначен для проведения учебных занятий фи...
# 259                                                NaN
# 265                                                NaN
# 270                                                NaN
# 271                                                NaN
#
#                                     Детальное описание  ...  \
# 54   Здание одноэтажное, без подвала, прямоугольное...  ...
# 259                                                NaN  ...
# 265                                                NaN  ...
# 270                                                NaN  ...
# 271                                                NaN  ...
#
#     Дата завершения строительства / реконструкции URL сайта  \
# 54                                     30.12.2015       NaN
# 259                                    25.12.2007       NaN
# 265                                    18.02.2008       NaN
# 270                                    07.09.2009       NaN
# 271                                    22.06.2010       NaN
#
#     Финансирование из федерального бюджета  \
# 54                             17500000.00
# 259                            17500000.00
# 265                            38900000.00
# 270                            60000000.00
# 271                            60000000.00
#
#      Финансирование из бюджета субъекта федерации  \
# 54                                     5500000.00
# 259                                          0.00
# 265                                          0.00
# 270                                          0.00
# 271                                          0.00
#
#      Финансирование из бюджета муниципального образования  \
# 54                                         24800000.00
# 259                                               0.00
# 265                                               0.00
# 270                                               0.00
# 271                                               0.00
#
#      Финансирование из внебюджетных источников  Активный Действия с объектом  \
# 54                                        0.00         Y       строительство
# 259                                       0.00         Y       строительство
# 265                                       0.00         Y       строительство
# 270                                       0.00         Y       строительство
# 271                                       0.00         Y       строительство
#
#     Общий объём финансирования. Проверка  sport_bool
# 54                           47800000.00
# 259                          17500000.00
# 265                          38900000.00
# 270                          60000000.00
# 271                          60000000.00
#
# [5 rows x 21 columns]

# %%
raw_data['Есть виды спорта'] = 'N'
raw_data['Есть виды спорта'] = raw_data['Есть виды спорта'].where(raw_data['Виды спорта'].isna(), 'Y')

# %%
#Посмотрим есть ли связь с Тип спортивного комплекса
table_sport_type =raw_data.pivot_table(index=
    'Тип спортивного комплекса', columns='Есть виды спорта',values = 'Адрес', aggfunc='count', fill_value = 0).reset_index()

table_sport_type['total'] =  table_sport_type['N'] + table_sport_type['Y']
table_sport_type['N'] = table_sport_type['N']/table_sport_type['total'] * 100
table_sport_type['Y'] = table_sport_type['Y']/table_sport_type['total'] * 100
table_sport_type[table_sport_type['N'] > 0]
# Out:
# Есть виды спорта                Тип спортивного комплекса          N  \
# 0                                           арена ледовая       2.70
# 1                                                 бассейн       6.00
# 2                                                велотрек      33.33
# 3                                          зал спортивный       3.81
# 7                               комплекс конно-спортивный      25.00
# 11                многофункциональный спортивный комплекс      11.30
# 13                                    площадка спортивная       9.09
# 14                                                стадион       4.23
# 17                                       футбольное поле        1.71
#
# Есть виды спорта          Y  total
# 0                     97.30     74
# 1                     94.00     50
# 2                     66.67      3
# 3                     96.19    105
# 7                     75.00      4
# 11                    88.70    301
# 13                    90.91     11
# 14                    95.77    142
# 17                    98.29    117

# %%
# Визуализируем
sns.set(style="whitegrid")
plt.figure(figsize = (5,7)) 
data = table_sport_type[table_sport_type['N'] > 0].sort_values(by = 'N' , ascending = False)
sns.barplot(y='Тип спортивного комплекса', x='N', data=data, palette="tab20", linewidth=2.5)
plt.title('Отсутвие описания видов спорта по типам спортивного комплекса', fontsize=15)
plt.ylabel("Тип")
plt.xlabel("Количество")
plt.show()

# %%
#Отлично сделаем на основании него Типа спорта. 
#Но похоже автоматизировать будет сложно. Если только не использовать  описание и вытянуть данные из него автопоиском.

# %%
# Возможно можно вытащить из описания?
raw_data['Краткое описание'][0]
# Out:
# 'МБОУ ДОД СДЮСШОР г. Советский единственное учреждение дополнительного образования детей физкультурно – спортивной направленности Советского района, центр физкультурно – оздоровительной и спортивной работы, осуществляющей подготовку детей на высоком уровне. В феврале 2009 года было введено в эксплуатацию здание «Крытого плавательного бассейна» общей площадью 5172,4 м2, вместимостью 110 чел. в час. В здании находятся ванны для плавания с шестью дорожками по 25м и малая ванна для обучения плаванию. Общей площадью зеркала воды 460 м2. Так же в здании находится зал «сухого» плавания для специальной физической подготовки пловцов и тренажерный зал, оборудованный современными тренажерами. К услугам посетителей имеются помещения двух саун. В здании «Крытого плавательного бассейна» располагается муниципальное образовательное учреждение дополнительного образования детей Детско-юношеская спортивная школа «Арена». В вечернее время всеми услугами плавательного бассейна активно пользуются жители города и района.'

# %%
# Вытащим список видов спорта
raw_data['Виды спорта'] = raw_data['Виды спорта'].replace('ё', 'е')
all_sports = []
for i in range(0,len(raw_data)):
    try:
        sports = raw_data.iloc[i]['Виды спорта']
        sport_list = sports.split(', ')
        for s in sport_list:
            all_sports.append(s)
    except:
            next
            
all_sports = set(all_sports)
#all_sports

# %%
# Лематизируем его
m = Mystem()
sport_lem = {}
for a in all_sports:
    v = a.lower()
    v = ''.join(m.lemmatize(str(v)))
    v = v.replace('\n', '')
    if v != 'го':
        sport_lem[v] = a

#sport_lem

# %%
#дополним логичными вариантам
sport_lem['фитнес'] = 'фитнес-аэробика'
sport_lem['аэробика'] = 'фитнес-аэробика'
sport_lem['плавательный'] = 'плавание'
sport_lem['бассейн'] = 'плавание'
sport_lem['ходьба'] = 'спортивная ходьба'
sport_lem['бильярд'] = 'бильярдный спорт'
sport_lem['единоборство'] = 'единоборства (разное)'
sport_lem['игровой'] = 'игровые виды спорта (разное)'
sport_lem['игровым'] = 'игровые виды спорта (разное)'
sport_lem['футбольный'] = 'футбол'
sport_lem['футбольно'] = 'футбол'
sport_lem['легкоатлетический'] = 'лёгкая атлетика'
sport_lem['легкоатлет'] = 'лёгкая атлетика'
sport_lem['конно'] = 'конный спорт'
sport_lem['конный'] = 'конный спорт'
sport_lem['физкультурный'] = 'общая физическая подготовка'

sport_lem
# Out:
# {'следж хоккей': 'следж хоккей',
#  'хоккей на трава': 'хоккей на траве',
#  'сават': 'сават',
#  'современный пятиборье': 'современное пятиборье',
#  'пауэрлифтинг': 'пауэрлифтинг',
#  'художественный гимнастика': 'художественная гимнастика',
#  'волейбол': 'волейбол',
#  'армспорт (армрестлинг)': 'армспорт (армрестлинг)',
#  'айкидо': 'айкидо',
#  'футбол лицо с заболевание цп': 'футбол лиц с заболеванием ЦП',
#  'парусный спорт': 'парусный спорт',
#  'кинологический спорт': 'кинологический спорт',
#  'мас-рестлинг': 'мас-рестлинг',
#  'фехтование': 'фехтование',
#  'греко-римский борьба': 'греко-римская борьба',
#  'регби на коляска': 'регби на колясках',
#  'практический стрельба': 'практическая стрельба',
#  'настольный теннис': 'настольный теннис',
#  'гандбол': 'гандбол',
#  'таеквандо': 'тхэквондо',
#  'перетягивание канат': 'перетягивание каната',
#  'борьба на пояс': 'борьба на поясах',
#  'спорт лицо с поражение ода': 'спорт лиц с поражением ОДА',
#  'карате': 'каратэ',
#  'бочча (паралимпийский вид)': 'бочча (паралимпийский вид)',
#  'американский футбол': 'американский футбол',
#  'пулевой стрельба': 'пулевая стрельба',
#  'танцевальный спорт': 'танцевальный спорт',
#  'гиревой спорт': 'гиревой спорт',
#  'конный спорт': 'конный спорт',
#  'полиатлон': 'полиатлон',
#  'боулинг': 'боулинг',
#  'силовой многоборье': 'силовое многоборье',
#  'сумо': 'сумо',
#  'велоспорт-маунтинбайк': 'велоспорт-маунтинбайк',
#  'кикбоксинг': 'кикбоксинг',
#  'прыжок на лыжа с трамплин': 'прыжки на лыжах с трамплина',
#  'русский лапта': 'русская лапта',
#  'керлинг': 'кёрлинг',
#  'дартс': 'дартс',
#  'авиамодельный спорт': 'авиамодельный спорт',
#  'хореография': 'хореография',
#  'гребля на байдарка и каноэ': 'гребля на байдарках и каноэ',
#  'самбо': 'самбо',
#  'капоэйр': 'капоэйра',
#  'бобслей': 'бобслей',
#  'единоборство (разный)': 'единоборства (разное)',
#  'мини-футбол': 'мини-футбол',
#  'спортивный гимнастика': 'спортивная гимнастика',
#  'бадминтон': 'бадминтон',
#  'горнолыжный спорт': 'горнолыжный спорт',
#  'пляжный волейбол': 'пляжный волейбол',
#  'северный многоборье': 'северное многоборье',
#  'бильярдный спорт': 'бильярдный спорт',
#  'академический гребля': 'академическая гребля',
#  'спортивный аэробика': 'спортивная аэробика',
#  'водный поло': 'водное поло',
#  'водно-моторный спорт': 'водно-моторный спорт',
#  'лыжный гонка': 'лыжные гонки',
#  'спорт лицо с интеллектуальный нарушение': 'спорт лиц с интеллектуальными нарушениями',
#  'бег': 'бег',
#  'силовой гимнастика': 'силовая гимнастика',
#  'спортивный ходьба': 'спортивная ходьба',
#  'сноуборд': 'сноуборд',
#  'альпинизм': 'альпинизм',
#  'фитнес-аэробика': 'фитнес-аэробика',
#  'вольный борьба': 'вольная борьба',
#  'флорбол': 'флорбол',
#  'биатлон': 'биатлон',
#  'джиу-джитсу': 'джиу-джитсу',
#  'гребной слалом': 'гребной слалом',
#  'общий физический подготовка': 'общая физическая подготовка',
#  'морской многоборье': 'морское многоборье',
#  'баскетбол': 'баскетбол',
#  'теннис': 'теннис',
#  'дзюдо': 'дзюдо',
#  'бодибилдинг': 'бодибилдинг',
#  'прыжок в длина': 'прыжки в длину',
#  'черлидинг': 'черлидинг',
#  'спортивный ориентирование': 'спортивное ориентирование',
#  'конькобежный спорт': 'конькобежный спорт',
#  'женский борьба': 'женская борьба',
#  'ушу': 'ушу',
#  'триатлон': 'триатлон',
#  'игровой вид спорт (разный)': 'игровые виды спорта (разное)',
#  'акробатический рок-н-ролл': 'акробатический рок-н-ролл',
#  'восточный боевой единоборство': 'восточное боевое единоборство',
#  'бейсбол': 'бейсбол',
#  'водный-лыжный спорт': 'водно-лыжный спорт',
#  'футбол': 'футбол',
#  'спорт слепой': 'спорт слепых',
#  'стендовый стрельба': 'стендовая стрельба',
#  'хоккей с мяч': 'хоккей с мячом',
#  'прыжок на батут': 'прыжки на батуте',
#  'стрельба из арбалет': 'стрельба из арбалета',
#  'синхронный плавание': 'синхронное плавание',
#  'хоккей': 'хоккей',
#  'шашка': 'шашки',
#  'волейбол сидеть': 'волейбол сидя',
#  'киокусинкай': 'киокусинкай',
#  'спортивный туризм': 'спортивный туризм',
#  'велоспорт-шоссе': 'велоспорт-шоссе',
#  'городошный спорт (городок)': 'городошный спорт (городки)',
#  'легкий атлетика': 'лёгкая атлетика',
#  'фигурный катание': 'фигурное катание',
#  'велоспорт-трек': 'велоспорт-трек',
#  'лыжный двоеборье': 'лыжное двоеборье',
#  'регби': 'регби',
#  'рукопашный бой': 'рукопашный бой',
#  'санный спорт': 'санный спорт',
#  'тайский бокс': 'тайский бокс',
#  'тяжелый атлетика': 'тяжёлая атлетика',
#  'плавание': 'плавание',
#  'аквааэробика': 'аквааэробика',
#  'подводный спорт': 'подводный спорт',
#  'велоспорт-вмх': 'велоспорт-ВМХ',
#  'скалолазание': 'скалолазание',
#  'спортивный бридж': 'спортивный бридж',
#  'фристайл': 'фристайл',
#  'эстетический гимнастика': 'эстетическая гимнастика',
#  'стрельба из лук': 'стрельба из лука',
#  'баскетбол на коляска': 'баскетбол на колясках',
#  'прыжок в вода': 'прыжки в воду',
#  'акватлон (подводный борьба)': 'акватлон (подводная борьба)',
#  'стритбол': 'стритбол',
#  'шахматы': 'шахматы',
#  'спортивный борьба': 'спортивная борьба',
#  'бокс': 'бокс',
#  'спорт глухой': 'спорт глухих',
#  'смешать боевой единоборство (мма)': 'смешанное боевое единоборство (ММА)',
#  'универсальный бой': 'универсальный бой',
#  'шейпинг': 'шейпинг',
#  'спортивный акробатика': 'спортивная акробатика',
#  'фитнес': 'фитнес-аэробика',
#  'аэробика': 'фитнес-аэробика',
#  'плавательный': 'плавание',
#  'бассейн': 'плавание',
#  'ходьба': 'спортивная ходьба',
#  'бильярд': 'бильярдный спорт',
#  'единоборство': 'единоборства (разное)',
#  'игровой': 'игровые виды спорта (разное)',
#  'игровым': 'игровые виды спорта (разное)',
#  'футбольный': 'футбол',
#  'футбольно': 'футбол',
#  'легкоатлетический': 'лёгкая атлетика',
#  'легкоатлет': 'лёгкая атлетика',
#  'конно': 'конный спорт',
#  'конный': 'конный спорт',
#  'физкультурный': 'общая физическая подготовка'}

# %%
# обработаем описание
raw_data['Описание'] = raw_data['Название'].astype(str) + " " +raw_data[
    'Краткое описание'].astype(str) + " " + raw_data['Детальное описание'].astype(str)
raw_data['Описание'] = raw_data['Описание'].str.lower()
raw_data['Описание'] = raw_data['Описание'].str.replace('ё', 'е')
raw_data['Описание'] = raw_data['Описание'].str.replace('.', ' ')
raw_data['Описание'] = raw_data['Описание'].str.replace(',', ' ')
raw_data['Описание'] = raw_data['Описание'].str.replace('&#', ' ')
raw_data['Описание'] = raw_data['Описание'].str.replace('&nbsp', ' ')
raw_data['Описание'] = raw_data['Описание'].str.replace('nannan', ' ')
raw_data['Описание'] = raw_data['Описание'].str.replace('nan', ' ')

raw_data['Описание'].head()
# Out:
# 0    крытый плавательный бассейн «садко» сдюсшор мб...
# 1    спортивный зал для мини-футбола отдельно стоящ...
# 2    ледовый дворец спорта ледовый дворец спорта в ...
# 3    спортивный центр с плавательным бассейном спор...
# 4    спортивный центр с универсальным игровым залом...
# Name: Описание, dtype: object

# %%
# пропусков нет
raw_data[raw_data['Описание'].isna()]
# Out:
# Empty DataFrame
# Columns: [Название, Адрес, Общий объём финансирования (руб.), Виды спорта, Субъект федерации, Тип спортивного комплекса, E-mail, Населённый пункт, Краткое описание, Детальное описание, Дата начала строительства / реконструкции, Дата завершения строительства / реконструкции, URL сайта, Финансирование из федерального бюджета, Финансирование из бюджета субъекта федерации, Финансирование из бюджета муниципального образования, Финансирование из внебюджетных источников, Активный, Действия с объектом, Общий объём финансирования. Проверка, sport_bool, Есть виды спорта, Описание]
# Index: []
#
# [0 rows x 23 columns]

# %%
# обработаем описание

def lem (base):
    text = base['Описание']
    return (' '.join(m.lemmatize((text))))

raw_data['Описание'] = raw_data.apply(lem, axis=1)

# %%
raw_data['Описание'] = raw_data['Описание'].str.replace('\n', ' ')
raw_data['Описание'] = raw_data['Описание'].str.replace('   ', ' ')
raw_data['Описание'] = raw_data['Описание'].str.replace('  ', ' ')
# пример
raw_data['Описание'][580]
# Out:
# 'центр олимпийский подготовка по спортивный ходьба центр олимпийский подготовка совмещать переход в здание крытый футбольный - легкоатлетический манеж на база объект быть располагаться гбу до « центр олимпийский подготовка республика мордовия по спортивный ходьба в м чегин » общий площадь здание – 12 043 51 м2  внутренний пространство комплекс предусматривать : - интернат на 73 человек для спортсмен заниматься легкий атлетика 40 48 номер 41 - зал для фитнес площадь 120 м2 - тренажерный зал 226 м2 - помещение медико - восстановительный центр 979 м2 - пищеблок с полный цикл на 100 место 40 обеденный зал на 70 место который быть работать по принцип « шведский стол » и банкетный зал на 30 место 41 - плавательный бассейн 25 х 16 м - административный помещение '

# %%
# есть ли пустоты
raw_data[raw_data['Описание'] == 'nan '].head(5)
# Out:
# Empty DataFrame
# Columns: [Название, Адрес, Общий объём финансирования (руб.), Виды спорта, Субъект федерации, Тип спортивного комплекса, E-mail, Населённый пункт, Краткое описание, Детальное описание, Дата начала строительства / реконструкции, Дата завершения строительства / реконструкции, URL сайта, Финансирование из федерального бюджета, Финансирование из бюджета субъекта федерации, Финансирование из бюджета муниципального образования, Финансирование из внебюджетных источников, Активный, Действия с объектом, Общий объём финансирования. Проверка, sport_bool, Есть виды спорта, Описание]
# Index: []
#
# [0 rows x 23 columns]

# %%
# наконец сведем их
mis_types = []

for i in raw_data.index.to_list():
        types = []
        for key, value in sport_lem.items():
            try:
                if key in raw_data['Описание'][i]:
                    types.append(sport_lem[key])
            except:
                print(raw_data['Описание'][i])
        mis_types.append(', '.join(set(types)))

mis_types[0:5]

raw_data['Виды спорта 2'] = mis_types
raw_data['Виды спорта'] = raw_data['Виды спорта'].where(raw_data['Есть виды спорта'] == 'Y' , raw_data['Виды спорта 2'])

# %%
# что с пропусками?
raw_data[raw_data['Виды спорта'].isna()]
# Out:
# Empty DataFrame
# Columns: [Название, Адрес, Общий объём финансирования (руб.), Виды спорта, Субъект федерации, Тип спортивного комплекса, E-mail, Населённый пункт, Краткое описание, Детальное описание, Дата начала строительства / реконструкции, Дата завершения строительства / реконструкции, URL сайта, Финансирование из федерального бюджета, Финансирование из бюджета субъекта федерации, Финансирование из бюджета муниципального образования, Финансирование из внебюджетных источников, Активный, Действия с объектом, Общий объём финансирования. Проверка, sport_bool, Есть виды спорта, Описание, Виды спорта 2]
# Index: []
#
# [0 rows x 24 columns]

# %%
# посмотрим визуально на то что нашли
raw_data['Виды спорта'] = raw_data['Виды спорта'].str.replace('  ', ' ')
raw_data[(raw_data['Есть виды спорта'] == 'N')].loc[:,['Виды спорта','Описание']].head()
# Out:
#                      Виды спорта  \
# 54
# 259  общая физическая подготовка
# 265  общая физическая подготовка
# 270
# 271
#
#                                               Описание
# 54   многофункциональный зал предназначать для пров...
# 259          физкультурный - оздоровительный комплекс
# 265   физкультурный - спортивный центр « локомотив »
# 270                                     фок « атал »
# 271                               фок « мариинский »

# %%
# проверим почему не нашли в описании.
raw_data['Описание'][54]
# Out:
# 'многофункциональный зал предназначать для проведение учебный занятие физический культура и спорт соревнование занятие в секция как школьников так и житель микрорайон здание одноэтажный без подвал прямоугольный с габарит в ось 54x18м  в состав многофункциональный зал \xa0 иметься набор следующий помещение : 1 41 комплекс раздевальный включать в себя раздевальный помещение для девочка и мальчик с - душевой кабина на 8 сетка каждый и санитарный узел на 2 кабинка каждый  2 41 помещение для преподавательский и тренерский состав  3 41 технический помещение включать в себя водомерный узел приточный вентиляционный камера вытяжной вентиляционный камера электрощитовая помещение моп '

# %%
# нашли 27. остальные удаляем т.к. не сможем найти инфмацию по олимпийскости видов спорта.
print("Нашли:",
      len(raw_data[(raw_data['Есть виды спорта'] == 'N') & (raw_data['Виды спорта'] != '')]))
print("НЕ нашли:",len(raw_data[(raw_data['Виды спорта'] == '')].loc[:,['Виды спорта','Описание']]))
# Out:
# Нашли: 27
# НЕ нашли: 27

# %%
#  остальные 28 удаляем
raw_data = raw_data[raw_data['Виды спорта'] != '']
raw_data.head()
# Out:
#                                           Название  \
# 0      Крытый плавательный бассейн «Садко» СДЮСШОР
# 1                  Спортивный зал для мини-футбола
# 2                            Ледовый дворец спорта
# 3        Спортивный центр с плавательным бассейном
# 4  Спортивный центр с универсальным игровым залом
#
#                                                Адрес  \
# 0  Ханты-Мансийский автономный округ, г. Советски...
# 1  Ханты-Мансийский автономный округ, г. Лангепас...
# 2  Ханты - Мансийский автономный округ, г. Сургут...
# 3  Ханты-Мансийский автономный округ, пос. Лыхма,...
# 4  Ханты-Мансийский автономный округ-Югра, г. Лан...
#
#    Общий объём финансирования (руб.)  \
# 0                       147105000.00
# 1                        83829000.00
# 2                       814724600.00
# 3                       212165000.00
# 4                       143946000.00
#
#                                          Виды спорта    Субъект федерации  \
# 0                                           плавание  Ханты-Мансийский АО
# 1  игровые виды спорта (разное), мини-футбол, общ...  Ханты-Мансийский АО
# 2  аквааэробика, греко-римская борьба, общая физи...  Ханты-Мансийский АО
# 3                             аквааэробика, плавание  Ханты-Мансийский АО
# 4  баскетбол, бодибилдинг, волейбол, настольный т...  Ханты-Мансийский АО
#
#                  Тип спортивного комплекса                 E-mail  \
# 0                                  бассейн          ukmps@mail.ru
# 1                           зал спортивный                    NaN
# 2                            арена ледовая        lds2011@list.ru
# 3  многофункциональный спортивный комплекс  NurtdinovRA@admbel.ru
# 4  многофункциональный спортивный комплекс                    NaN
#
#   Населённый пункт                                   Краткое описание  \
# 0     г. Советский  МБОУ ДОД СДЮСШОР г. Советский единственное учр...
# 1      г. Лангепас  Отдельно стоящее здание, расположено на обособ...
# 2        г. Сургут  Ледовый Дворец спорта в городе Сургуте открыт ...
# 3       пос. Лыхма  Спортивный центр с плавательным бассейном в п....
# 4      г. Лангепас  Отдельно стоящее здание, расположено на обособ...
#
#                                   Детальное описание  ...  \
# 0  Общая площадь здания «Крытого плавательного ба...  ...
# 1  Здание кирпичное, бетонное, блоки «Сэндвичи». ...  ...
# 2  Общая площадь объекта составляет 21 247 м2. Пе...  ...
# 3  Общая площадь объекта составляет 2111 м2. Пере...  ...
# 4  Общая площадь объекта составляет 3092,8 м2. Пе...  ...
#
#   Финансирование из бюджета субъекта федерации  \
# 0                                 132844000.00
# 1                                  63014000.00
# 2                                   8293100.00
# 3                                 150646000.00
# 4                                 114058000.00
#
#   Финансирование из бюджета муниципального образования  \
# 0                                         4261000.00
# 1                                         3315000.00
# 2                                       587035000.00
# 3                                         1519000.00
# 4                                        12388000.00
#
#   Финансирование из внебюджетных источников  Активный  Действия с объектом  \
# 0                                      0.00         Y        строительство
# 1                                      0.00         Y        строительство
# 2                              129396500.00         Y        строительство
# 3                                      0.00         Y        строительство
# 4                                      0.00         Y        строительство
#
#    Общий объём финансирования. Проверка  sport_bool Есть виды спорта  \
# 0                          147105000.00       False                Y
# 1                           83829000.00       False                Y
# 2                          814724600.00       False                Y
# 3                          212165000.00       False                Y
# 4                          143946000.00        True                Y
#
#                                             Описание  \
# 0  крытый плавательный бассейн « садко » сдюсшор ...
# 1  спортивный зал для мини-футбол отдельно стоящи...
# 2  ледовый дворец спорт ледовый дворец спорт в го...
# 3  спортивный центр с плавательный бассейн спорти...
# 4  спортивный центр с универсальный игровой зал о...
#
#                                        Виды спорта 2
# 0              общая физическая подготовка, плавание
# 1                                футбол, мини-футбол
# 2  шахматы, хореография, фигурное катание, плаван...
# 3  общая физическая подготовка, игровые виды спор...
# 4  баскетбол, настольный теннис, теннис, игровые ...
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Итог
# <a name="18."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
# поменяем типы на даты

raw_data['Дата начала строительства / реконструкции'] = pd.to_datetime(raw_data[
    'Дата начала строительства / реконструкции'], format='%d.%m.%Y')
raw_data['Дата завершения строительства / реконструкции'] = pd.to_datetime(raw_data[
    'Дата завершения строительства / реконструкции'], format='%d.%m.%Y')

# %%
# откинем лишние столбцы
clean_data = raw_data[need_columns_extended].reset_index(drop=True)

# %%
#распечатаем базовую инфо
print_basic_info(clean_data,1,0,1,0)
# Out:
#   info
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 810 entries, 0 to 809
# Data columns (total 19 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Название                                              810 non-null    object
#  1   Адрес                                                 810 non-null    object
#  2   Общий объём финансирования (руб.)                     810 non-null    float64
#  3   Виды спорта                                           810 non-null    object
#  4   Субъект федерации                                     810 non-null    object
#  5   Тип спортивного комплекса                             810 non-null    object
#  6   E-mail                                                458 non-null    object
#  7   Населённый пункт                                      810 non-null    object
#  8   Краткое описание                                      750 non-null    object
#  9   Детальное описание                                    634 non-null    object
#  10  Дата начала строительства / реконструкции             698 non-null    datetime64[ns]
#  11  Дата завершения строительства / реконструкции         797 non-null    datetime64[ns]
#  12  URL сайта                                             86 non-null     object
#  13  Финансирование из федерального бюджета                810 non-null    float64
#  14  Финансирование из бюджета субъекта федерации          810 non-null    float64
#  15  Финансирование из бюджета муниципального образования  810 non-null    float64
#  16  Финансирование из внебюджетных источников             810 non-null    float64
#  17  Активный                                              810 non-null    object
#  18  Действия с объектом                                   810 non-null    object
# dtypes: datetime64[ns](2), float64(5), object(12)
# memory usage: 120.4+ KB
# None
#
#   duplicated
#
# 0

# %%
print_basic_info(clean_data,0,0,0,5)
# Out:
#   head
#                                           Название  \
# 0      Крытый плавательный бассейн «Садко» СДЮСШОР
# 1                  Спортивный зал для мини-футбола
# 2                            Ледовый дворец спорта
# 3        Спортивный центр с плавательным бассейном
# 4  Спортивный центр с универсальным игровым залом
#
#                                                Адрес  \
# 0  Ханты-Мансийский автономный округ, г. Советски...
# 1  Ханты-Мансийский автономный округ, г. Лангепас...
# 2  Ханты - Мансийский автономный округ, г. Сургут...
# 3  Ханты-Мансийский автономный округ, пос. Лыхма,...
# 4  Ханты-Мансийский автономный округ-Югра, г. Лан...
#
#    Общий объём финансирования (руб.)  \
# 0                       147105000.00
# 1                        83829000.00
# 2                       814724600.00
# 3                       212165000.00
# 4                       143946000.00
#
#                                          Виды спорта    Субъект федерации  \
# 0                                           плавание  Ханты-Мансийский АО
# 1  игровые виды спорта (разное), мини-футбол, общ...  Ханты-Мансийский АО
# 2  аквааэробика, греко-римская борьба, общая физи...  Ханты-Мансийский АО
# 3                             аквааэробика, плавание  Ханты-Мансийский АО
# 4  баскетбол, бодибилдинг, волейбол, настольный т...  Ханты-Мансийский АО
#
#                  Тип спортивного комплекса                 E-mail  \
# 0                                  бассейн          ukmps@mail.ru
# 1                           зал спортивный                    NaN
# 2                            арена ледовая        lds2011@list.ru
# 3  многофункциональный спортивный комплекс  NurtdinovRA@admbel.ru
# 4  многофункциональный спортивный комплекс                    NaN
#
#   Населённый пункт                                   Краткое описание  \
# 0     г. Советский  МБОУ ДОД СДЮСШОР г. Советский единственное учр...
# 1      г. Лангепас  Отдельно стоящее здание, расположено на обособ...
# 2        г. Сургут  Ледовый Дворец спорта в городе Сургуте открыт ...
# 3       пос. Лыхма  Спортивный центр с плавательным бассейном в п....
# 4      г. Лангепас  Отдельно стоящее здание, расположено на обособ...
#
#                                   Детальное описание  \
# 0  Общая площадь здания «Крытого плавательного ба...
# 1  Здание кирпичное, бетонное, блоки «Сэндвичи». ...
# 2  Общая площадь объекта составляет 21 247 м2. Пе...
# 3  Общая площадь объекта составляет 2111 м2. Пере...
# 4  Общая площадь объекта составляет 3092,8 м2. Пе...
#
#   Дата начала строительства / реконструкции  \
# 0                                2006-12-01
# 1                                2007-06-01
# 2                                2008-06-01
# 3                                2006-12-15
# 4                                2008-01-14
#
#   Дата завершения строительства / реконструкции URL сайта  \
# 0                                    2008-12-31       NaN
# 1                                    2009-12-30       NaN
# 2                                    2011-11-05       NaN
# 3                                    2009-12-24       NaN
# 4                                    2011-12-30       NaN
#
#    Финансирование из федерального бюджета  \
# 0                             10000000.00
# 1                             17500000.00
# 2                             90000000.00
# 3                             60000000.00
# 4                             17500000.00
#
#    Финансирование из бюджета субъекта федерации  \
# 0                                  132844000.00
# 1                                   63014000.00
# 2                                    8293100.00
# 3                                  150646000.00
# 4                                  114058000.00
#
#    Финансирование из бюджета муниципального образования  \
# 0                                         4261000.00
# 1                                         3315000.00
# 2                                       587035000.00
# 3                                         1519000.00
# 4                                        12388000.00
#
#    Финансирование из внебюджетных источников Активный Действия с объектом
# 0                                       0.00        Y       строительство
# 1                                       0.00        Y       строительство
# 2                               129396500.00        Y       строительство
# 3                                       0.00        Y       строительство
# 4                                       0.00        Y       строительство

# %% [markdown]
# ## 2. **Срез данных по списку спортивных объектов**
# <a name="2."></a>
#
# ### Что необходимо досчитать
# <a name="20."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
#Какие колонки нам нужны для выгрузки для клиента
client_columns = ["Название","Адрес",
                "Тип населенного пункта","Почтовый индекс",
                "E-mail","Даты крупных соревнований и значимых событий",
                "Общий объём финансирования (руб.)",
                "Общий объём финансирования (EUR)",
                "Общий объём финансирования (USD)",
                "Доля от объема финансирования в регионе",
                "Продолжительность строительства/реконструкции (дней)",
                "Наличие зимних олимписких видов спорта в видах спорта объекта"]

# %%
#Найдем сходствл в кейсах
def intersection(first, second):
    return [item for item in first if item in second]

#есть в wire, но нет в bulk
intersection_list  = intersection(raw_columns_list, client_columns)
intersection_list
# Out:
# ['Название', 'Адрес', 'Общий объём финансирования (руб.)', 'E-mail']

# %%
#Найдем различие в кейсах
def diff(first, second):
    return [item for item in first if item not in second]

#есть в wire, но нет в bulk
diff_list  = diff(client_columns, raw_columns_list)
diff_list
# Out:
# ['Тип населенного пункта',
#  'Почтовый индекс',
#  'Даты крупных соревнований и значимых событий',
#  'Общий объём финансирования (EUR)',
#  'Общий объём финансирования (USD)',
#  'Доля от объема финансирования в регионе',
#  'Продолжительность строительства/реконструкции (дней)',
#  'Наличие зимних олимписких видов спорта в видах спорта объекта']

# %% [markdown]
# Это  то, что нужно досчитать

# %% [markdown]
# #### "Тип населенного пункта"
# <a name="21."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
# найдем по адресу
locality = clean_data['Населённый пункт'].str.split(" ", n = 1, expand = True )
locality['Адрес'] = clean_data['Адрес']
locality.head()
# Out:
#       0          1                                              Адрес
# 0    г.  Советский  Ханты-Мансийский автономный округ, г. Советски...
# 1    г.   Лангепас  Ханты-Мансийский автономный округ, г. Лангепас...
# 2    г.     Сургут  Ханты - Мансийский автономный округ, г. Сургут...
# 3  пос.      Лыхма  Ханты-Мансийский автономный округ, пос. Лыхма,...
# 4    г.   Лангепас  Ханты-Мансийский автономный округ-Югра, г. Лан...

# %%
# обработаем
locality[0].value_counts()
# Out:
# г.              553
# с.              127
# пос.             55
# пгт              48
# ст.               9
# дер.              8
# р.п.              5
# аул               2
# Приволжский       1
# Николаевская      1
# р.п.Колывань      1
# Name: 0, dtype: int64

# %%
# обработаем 
locality[0] = locality[0].replace('р.п.Колывань', 'р.п.')
locality[0] = locality[0].replace('Приволжский', '').replace('Николаевская', '')
locality[0] = locality[0].str.replace('.', '')
locality[0] = locality[0].replace('г', 'город').replace('го', 'город')
locality[0] = locality[0].replace('рабочий', 'рабочий посёлок').replace('рп', 'рабочий посёлок')
locality[0] = locality[0].replace('пос', 'посёлок').replace('сп', 'посёлок')
locality[0] = locality[0].replace('ст', 'станица').replace('с', 'село').replace(
    'дер', 'деревня')

locality[0].value_counts()
# Out:
# город              553
# село               127
# посёлок             55
# пгт                 48
# станица              9
# деревня              8
# рабочий посёлок      6
# аул                  2
#                      2
# Name: 0, dtype: int64

# %%
# проверим одиночек
locality[locality[0] == '']
# Out:
#     0      1                                              Адрес
# 26     сопка  Красноярский край, Николаевская сопка, ул. Биа...
# 474    район  Ивановская область, Приволжский район 400 м на...

# %%
# заполним руками
locality.iloc[26,0] = 'город'
locality.iloc[474,0] = 'город'

# %%
print("Пропуски" ,len(locality[locality[0] == ''])
, "+", len(locality[locality[0].isna()]))
# Out:
# Пропуски 0 + 0

# %%
locality[0].value_counts()
# Out:
# город              555
# село               127
# посёлок             55
# пгт                 48
# станица              9
# деревня              8
# рабочий посёлок      6
# аул                  2
# Name: 0, dtype: int64

# %%
clean_data['Тип населенного пункта']  = locality[0]

clean_data.head(3)
# Out:
#                                       Название  \
# 0  Крытый плавательный бассейн «Садко» СДЮСШОР
# 1              Спортивный зал для мини-футбола
# 2                        Ледовый дворец спорта
#
#                                                Адрес  \
# 0  Ханты-Мансийский автономный округ, г. Советски...
# 1  Ханты-Мансийский автономный округ, г. Лангепас...
# 2  Ханты - Мансийский автономный округ, г. Сургут...
#
#    Общий объём финансирования (руб.)  \
# 0                       147105000.00
# 1                        83829000.00
# 2                       814724600.00
#
#                                          Виды спорта    Субъект федерации  \
# 0                                           плавание  Ханты-Мансийский АО
# 1  игровые виды спорта (разное), мини-футбол, общ...  Ханты-Мансийский АО
# 2  аквааэробика, греко-римская борьба, общая физи...  Ханты-Мансийский АО
#
#   Тип спортивного комплекса           E-mail Населённый пункт  \
# 0                   бассейн    ukmps@mail.ru     г. Советский
# 1            зал спортивный              NaN      г. Лангепас
# 2             арена ледовая  lds2011@list.ru        г. Сургут
#
#                                     Краткое описание  \
# 0  МБОУ ДОД СДЮСШОР г. Советский единственное учр...
# 1  Отдельно стоящее здание, расположено на обособ...
# 2  Ледовый Дворец спорта в городе Сургуте открыт ...
#
#                                   Детальное описание  \
# 0  Общая площадь здания «Крытого плавательного ба...
# 1  Здание кирпичное, бетонное, блоки «Сэндвичи». ...
# 2  Общая площадь объекта составляет 21 247 м2. Пе...
#
#   Дата начала строительства / реконструкции  \
# 0                                2006-12-01
# 1                                2007-06-01
# 2                                2008-06-01
#
#   Дата завершения строительства / реконструкции URL сайта  \
# 0                                    2008-12-31       NaN
# 1                                    2009-12-30       NaN
# 2                                    2011-11-05       NaN
#
#    Финансирование из федерального бюджета  \
# 0                             10000000.00
# 1                             17500000.00
# 2                             90000000.00
#
#    Финансирование из бюджета субъекта федерации  \
# 0                                  132844000.00
# 1                                   63014000.00
# 2                                    8293100.00
#
#    Финансирование из бюджета муниципального образования  \
# 0                                         4261000.00
# 1                                         3315000.00
# 2                                       587035000.00
#
#    Финансирование из внебюджетных источников Активный Действия с объектом  \
# 0                                       0.00        Y       строительство
# 1                                       0.00        Y       строительство
# 2                               129396500.00        Y       строительство
#
#   Тип населенного пункта
# 0                  город
# 1                  город
# 2                  город

# %% [markdown]
# #### Почтовый индекс
# <a name="22."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
# по адресу определим индекс
clean_data['Почтовый индекс'] = None

# %%
def BS(page_text):
    page_bs = None
    page_bs = BeautifulSoup(page_text)
    return page_bs

def find_index(base):
    adress = base['Адрес']
    # наш url с информацией
    url = "https://indexphone.ru/?search=" + adress.replace(" ", "+")
    response = requests.get(url, headers=headers, allow_redirects=True)
    page_text = ''
    if response.status_code == 200:
        # BeautifulSoup
        page_bs = BS(response.text)
        try:
            # вытащим нужный кусок (если он есть)
            index = page_bs.find('span', {'class': 'post-search-list-postalcode'}).text
        except:
            return None
        return index 
    else:
        print(f'Ошибка! Response code: {response.status_code}')
        print(f'URL: {url}')
        print('--------------')
    

# т.к. вытягиваем по адресу должны много поймать 
clean_data['Почтовый индекс'] = clean_data.apply(find_index, axis=1)

# %%
print("Пропуски" ,len(clean_data[clean_data['Почтовый индекс'] == ''])
, "+ ", len(clean_data[clean_data['Почтовый индекс'].isna()]))

# в 16 случаях по адресу индекс не нашелся
# Out:
# Пропуски 0 +  16

# %%
#set(clean_data['Почтовый индекс'].to_list())

# %% [markdown]
# #### Даты крупных соревнований и значимых событий
# <a name="23."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
# Даты крупных соревнований и значимых событий вытащим из краткого описания. 

events = clean_data['Краткое описание'].str.split('Даты крупных соревнований и значимых событий:', expand = True)

# %%
events
# Рассмотрим ближе что во 2 столбце и 1.
# Out:
#                                                      0  \
# 0    МБОУ ДОД СДЮСШОР г. Советский единственное учр...
# 1    Отдельно стоящее здание, расположено на обособ...
# 2    Ледовый Дворец спорта в городе Сургуте открыт ...
# 3    Спортивный центр с плавательным бассейном в п....
# 4    Отдельно стоящее здание, расположено на обособ...
# ..                                                 ...
# 805  Проводятся занятия детей ДЮСШ, групп здоровья ...
# 806                                                NaN
# 807  Реконструкция футбольного поля способствует  п...
# 808  Строительство ФОК способствует увеличению коли...
# 809  Спортивная инфраструктура Нолинского района по...
#
#                                                      1     2
# 0                                                 None  None
# 1     Финал Кубка России среди юношей 2000г.р. по м...  None
# 2     - 05, 06 марта 2013 года – Первенство России ...  None
# 3                                                 None  None
# 4                                                 None  None
# ..                                                 ...   ...
# 805                                               None  None
# 806                                                NaN   NaN
# 807                                               None  None
# 808                                               None  None
# 809                                               None  None
#
# [810 rows x 3 columns]

# %%
# сколько таких
len(events[events[2].isna() == False])
# Out:
# 2

# %%
events[events[2].isna() == False].iloc[0,1]
# Out:
# ' Кубок России, Чемпионат и первенство России, Спартакиада молодежи, Водный турнир на призы ИППО. '

# %%
events[events[2].isna() == False].iloc[0,2]
# Out:
# ' Кубок России, Чемпионат и первенство России, Спартакиада молодежи, Водный турнир на призы ИППО. 08.05.2015 – 11.05.2015 – Кубок России по гребному слалому  21.07.2015 – 26.07.2015 – Чемпионат России по гребному слалому.  В конце июля открылся центр гребного слалома в Окуловке Завершилось строительство «Регионального центра гребного слалома в г. Окуловка» Новгородской области на реке Перетно. Церемонию открытия спортивного объекта была приурочена к проведению чемпионата России по гребному слалому, который проходил в Окуловке с 21 по 26 июля 2015 года. Объект предназначен для проведения тренировок и соревнований по гребному слалому. В состав центра гребного слалома входят эллинги для хранения лодок, административное здание с медпунктом, тренажерным залом, кафе, судейскими и тренерскими комнатами, а также хозяйственно-бытовой блок со столовой и подсобными помещениями. Кроме того, на базе объекта установлена сцена для проведения торжественных церемоний и зона активного отдыха. Берега реки Перетна укреплены габионными конструкциями в виде террас со зрительскими трибунами.  В обычном режиме число одновременно занимающихся спортсменов составит 50 человек в час, число зрителей – 20 человек, число обслуживающего персонала – 10 человек. В период проведения соревнований число участников может составить 300 человек, число зрителей – 500 человек, число обслуживающего персонала – 100 человек.  Возведение объекта проводилось в рамках реализации Федеральной целевой программы «Развитие физической культуры и спорта в Российской Федерации на 2006-2015 годы». Из федерального бюджета на строительство было выделено 70 млн рублей.'

# %%
# Берем 2 и пишем в 1

events[1] = events[1].where(events[2].isna(), events[2])

# %%
# А теперь  поправим битые символы аски кодов
events[1][785]
# Out:
# ' День рождение спорткомплекса – декабрь &#40 отчетное мероприятие за год&#41   Кубок Заполярного района – 28 февраля  Межмуниципальная Спартакиада – 28 марта – 2 апреля. '

# %%
events[1] = events[1].str.replace('&#37', '%')
events[1] = events[1].str.replace('&#40', '(')
events[1] = events[1].str.replace('&#41', ')')
events[1] = events[1].str.replace('&#43', '+')
events[1] = events[1].str.replace('\xa0', ' ')
events[1] = events[1].str.replace('&#96', "'")
events[1] = events[1].str.replace('&#1', " ")

events
# Out:
#                                                      0  \
# 0    МБОУ ДОД СДЮСШОР г. Советский единственное учр...
# 1    Отдельно стоящее здание, расположено на обособ...
# 2    Ледовый Дворец спорта в городе Сургуте открыт ...
# 3    Спортивный центр с плавательным бассейном в п....
# 4    Отдельно стоящее здание, расположено на обособ...
# ..                                                 ...
# 805  Проводятся занятия детей ДЮСШ, групп здоровья ...
# 806                                                NaN
# 807  Реконструкция футбольного поля способствует  п...
# 808  Строительство ФОК способствует увеличению коли...
# 809  Спортивная инфраструктура Нолинского района по...
#
#                                                      1     2
# 0                                                 None  None
# 1     Финал Кубка России среди юношей 2000г.р. по м...  None
# 2     - 05, 06 марта 2013 года – Первенство России ...  None
# 3                                                 None  None
# 4                                                 None  None
# ..                                                 ...   ...
# 805                                               None  None
# 806                                                NaN   NaN
# 807                                               None  None
# 808                                               None  None
# 809                                               None  None
#
# [810 rows x 3 columns]

# %%
events[1][785]
# Out:
# ' День рождение спорткомплекса – декабрь ( отчетное мероприятие за год)   Кубок Заполярного района – 28 февраля  Межмуниципальная Спартакиада – 28 марта – 2 апреля. '

# %%
clean_data['Даты крупных соревнований и значимых событий'] = events[1]

# %%
# нашли 197 кейсов 

len(clean_data[clean_data['Даты крупных соревнований и значимых событий'].isna() == False])
# Out:
# 197

# %% [markdown]
# #### Общий объём финансирования EUR и USD
# <a name="24."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
# сегодня
dt = datetime.datetime.today().strftime("%d.%m.%Y")

# %%
def currency_by_date(COD, dt):
    # Отсюда распарсим курс табличкой
    url = 'https://cbr.ru/currency_base/daily/?UniDbQuery.Posted=True&UniDbQuery.To=' + dt
    try:
        table = pd.read_html(url)[0]
        table['Курс_1_рублю'] = table['Курс']/10000 / table['Единиц']
        return table[table['Букв. код'] == COD]['Курс_1_рублю'].values[0]
    except: 
        return None

# %%
# рассчет EUR
COD = 'EUR'
dt = datetime.datetime.today().strftime("%d.%m.%Y")

clean_data['EUR_today'] = currency_by_date(COD, dt)
clean_data['Общий объём финансирования (EUR)'] = clean_data['Общий объём финансирования (руб.)'] / clean_data['EUR_today']

# %%
# проверка
print("Пропуски" ,len(clean_data[clean_data['Общий объём финансирования (EUR)'] == 0])
, "+ ", len(clean_data[clean_data['Общий объём финансирования (EUR)'].isna()]))
# Out:
# Пропуски 0 +  0

# %%
# рассчет USD, вытаскиваем нужную дату

def USD_date(base):
    COD = 'USD'
    dt = base['end_date']
    try:
        return currency_by_date(COD, dt)
    except: 
        return None

    
clean_data['end_date'] = clean_data['Дата завершения строительства / реконструкции'].dt.strftime("%d.%m.%Y")
clean_data['USD_date'] = clean_data.apply(USD_date, axis=1)

# %%
clean_data['Общий объём финансирования (USD)'] = clean_data[
    'Общий объём финансирования (руб.)'] / clean_data['USD_date']

# %%
# У кого нет информации о дате?
print(len(clean_data[clean_data['Дата завершения строительства / реконструкции'].isna()]))
# Out:
# 13

# %%
# проверим

# %%
clean_data[(clean_data['Общий объём финансирования (USD)'].isna() == False ) & clean_data[
    'Дата завершения строительства / реконструкции'].isna()]['Дата завершения строительства / реконструкции']
# Out:
# Series([], Name: Дата завершения строительства / реконструкции, dtype: datetime64[ns])

# %%
# проверка
print("Пропуски" ,len(clean_data[clean_data['Общий объём финансирования (USD)'] == 0])
, "+ ", len(clean_data[clean_data['Общий объём финансирования (USD)'].isna()]))

clean_data.head(3)
# Out:
# Пропуски 0 +  13
#                                       Название  \
# 0  Крытый плавательный бассейн «Садко» СДЮСШОР
# 1              Спортивный зал для мини-футбола
# 2                        Ледовый дворец спорта
#
#                                                Адрес  \
# 0  Ханты-Мансийский автономный округ, г. Советски...
# 1  Ханты-Мансийский автономный округ, г. Лангепас...
# 2  Ханты - Мансийский автономный округ, г. Сургут...
#
#    Общий объём финансирования (руб.)  \
# 0                       147105000.00
# 1                        83829000.00
# 2                       814724600.00
#
#                                          Виды спорта    Субъект федерации  \
# 0                                           плавание  Ханты-Мансийский АО
# 1  игровые виды спорта (разное), мини-футбол, общ...  Ханты-Мансийский АО
# 2  аквааэробика, греко-римская борьба, общая физи...  Ханты-Мансийский АО
#
#   Тип спортивного комплекса           E-mail Населённый пункт  \
# 0                   бассейн    ukmps@mail.ru     г. Советский
# 1            зал спортивный              NaN      г. Лангепас
# 2             арена ледовая  lds2011@list.ru        г. Сургут
#
#                                     Краткое описание  \
# 0  МБОУ ДОД СДЮСШОР г. Советский единственное учр...
# 1  Отдельно стоящее здание, расположено на обособ...
# 2  Ледовый Дворец спорта в городе Сургуте открыт ...
#
#                                   Детальное описание  ... Активный  \
# 0  Общая площадь здания «Крытого плавательного ба...  ...        Y
# 1  Здание кирпичное, бетонное, блоки «Сэндвичи». ...  ...        Y
# 2  Общая площадь объекта составляет 21 247 м2. Пе...  ...        Y
#
#   Действия с объектом Тип населенного пункта  Почтовый индекс  \
# 0       строительство                  город           628240
# 1       строительство                  город           628671
# 2       строительство                  город           628408
#
#         Даты крупных соревнований и значимых событий  EUR_today  \
# 0                                               None      82.64
# 1   Финал Кубка России среди юношей 2000г.р. по м...      82.64
# 2   - 05, 06 марта 2013 года – Первенство России ...      82.64
#
#    Общий объём финансирования (EUR)    end_date   USD_date  \
# 0                        1780072.34  31.12.2008      29.38
# 1                        1014388.93  30.12.2009      29.85
# 2                        9858731.68  05.11.2011      30.84
#
#   Общий объём финансирования (USD)
# 0                       5006909.37
# 1                       2808426.38
# 2                      26414533.88
#
# [3 rows x 27 columns]

# %%
clean_data['USD_date'].describe()
# Out:
# count       797.00
# mean         37.43
# std          14.56
# min          23.33
# 25%          29.93
# 50%          31.06
# 75%          35.02
# max          79.50
# Name: USD_date, dtype: float64

# %% [markdown]
# #### Доля от объема финансирования в регионе
# <a name="25."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
# найдем сумму 
sub_sum = clean_data.groupby(['Субъект федерации'])['Общий объём финансирования (руб.)'].sum().reset_index()
sub_sum.columns = ['Субъект федерации', 'Суммарный объем финансирования - строительство (руб.)']
sub_sum
# Out:
#         Субъект федерации  \
# 0          Алтайский край
# 1        Амурская область
# 2   Архангельская область
# 3    Астраханская область
# 4    Белгородская область
# ..                    ...
# 77    Ханты-Мансийский АО
# 78    Челябинская область
# 79   Чеченская Республика
# 80      Ямало-Ненецкий АО
# 81    Ярославская область
#
#     Суммарный объем финансирования - строительство (руб.)
# 0                                        465988021.00
# 1                                        243921000.00
# 2                                        922821600.00
# 3                                       2924360433.00
# 4                                        871190000.00
# ..                                                ...
# 77                                      2146055710.00
# 78                                       438272022.00
# 79                                       374569000.00
# 80                                        18000000.00
# 81                                      1229190000.00
#
# [82 rows x 2 columns]

# %%
# найдем долю 
clean_data = clean_data.merge(sub_sum, on = 'Субъект федерации')
clean_data['Доля от объема финансирования в регионе'] =  clean_data['Общий объём финансирования (руб.)'] / clean_data['Суммарный объем финансирования - строительство (руб.)']

# %%
# проверим
print("Пропуски" ,len(clean_data[clean_data['Доля от объема финансирования в регионе'] == 0])
, "+ ", len(clean_data[clean_data['Доля от объема финансирования в регионе'].isna()]))

clean_data.head()
# Out:
# Пропуски 0 +  0
#                                           Название  \
# 0      Крытый плавательный бассейн «Садко» СДЮСШОР
# 1                  Спортивный зал для мини-футбола
# 2                            Ледовый дворец спорта
# 3        Спортивный центр с плавательным бассейном
# 4  Спортивный центр с универсальным игровым залом
#
#                                                Адрес  \
# 0  Ханты-Мансийский автономный округ, г. Советски...
# 1  Ханты-Мансийский автономный округ, г. Лангепас...
# 2  Ханты - Мансийский автономный округ, г. Сургут...
# 3  Ханты-Мансийский автономный округ, пос. Лыхма,...
# 4  Ханты-Мансийский автономный округ-Югра, г. Лан...
#
#    Общий объём финансирования (руб.)  \
# 0                       147105000.00
# 1                        83829000.00
# 2                       814724600.00
# 3                       212165000.00
# 4                       143946000.00
#
#                                          Виды спорта    Субъект федерации  \
# 0                                           плавание  Ханты-Мансийский АО
# 1  игровые виды спорта (разное), мини-футбол, общ...  Ханты-Мансийский АО
# 2  аквааэробика, греко-римская борьба, общая физи...  Ханты-Мансийский АО
# 3                             аквааэробика, плавание  Ханты-Мансийский АО
# 4  баскетбол, бодибилдинг, волейбол, настольный т...  Ханты-Мансийский АО
#
#                  Тип спортивного комплекса                 E-mail  \
# 0                                  бассейн          ukmps@mail.ru
# 1                           зал спортивный                    NaN
# 2                            арена ледовая        lds2011@list.ru
# 3  многофункциональный спортивный комплекс  NurtdinovRA@admbel.ru
# 4  многофункциональный спортивный комплекс                    NaN
#
#   Населённый пункт                                   Краткое описание  \
# 0     г. Советский  МБОУ ДОД СДЮСШОР г. Советский единственное учр...
# 1      г. Лангепас  Отдельно стоящее здание, расположено на обособ...
# 2        г. Сургут  Ледовый Дворец спорта в городе Сургуте открыт ...
# 3       пос. Лыхма  Спортивный центр с плавательным бассейном в п....
# 4      г. Лангепас  Отдельно стоящее здание, расположено на обособ...
#
#                                   Детальное описание  ...  \
# 0  Общая площадь здания «Крытого плавательного ба...  ...
# 1  Здание кирпичное, бетонное, блоки «Сэндвичи». ...  ...
# 2  Общая площадь объекта составляет 21 247 м2. Пе...  ...
# 3  Общая площадь объекта составляет 2111 м2. Пере...  ...
# 4  Общая площадь объекта составляет 3092,8 м2. Пе...  ...
#
#   Тип населенного пункта Почтовый индекс  \
# 0                  город          628240
# 1                  город          628671
# 2                  город          628408
# 3                посёлок          628173
# 4                  город          628672
#
#         Даты крупных соревнований и значимых событий  EUR_today  \
# 0                                               None      82.64
# 1   Финал Кубка России среди юношей 2000г.р. по м...      82.64
# 2   - 05, 06 марта 2013 года – Первенство России ...      82.64
# 3                                               None      82.64
# 4                                               None      82.64
#
#    Общий объём финансирования (EUR)    end_date   USD_date  \
# 0                        1780072.34  31.12.2008      29.38
# 1                        1014388.93  30.12.2009      29.85
# 2                        9858731.68  05.11.2011      30.84
# 3                        2567343.38  24.12.2009      30.50
# 4                        1741846.25  30.12.2011      32.02
#
#   Общий объём финансирования (USD)  \
# 0                       5006909.37
# 1                       2808426.38
# 2                      26414533.88
# 3                       6956069.86
# 4                       4495544.93
#
#   Суммарный объем финансирования - строительство (руб.)  \
# 0                                      2146055710.00
# 1                                      2146055710.00
# 2                                      2146055710.00
# 3                                      2146055710.00
# 4                                      2146055710.00
#
#   Доля от объема финансирования в регионе
# 0                                    0.07
# 1                                    0.04
# 2                                    0.38
# 3                                    0.10
# 4                                    0.07
#
# [5 rows x 29 columns]

# %% [markdown]
# #### "Продолжительность строительства/реконструкции (дней)"
# <a name="26."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
# расчитаем

clean_data['Продолжительность строительства/реконструкции (дней)'] = (clean_data[
    'Дата завершения строительства / реконструкции'] - clean_data[
    'Дата начала строительства / реконструкции']) / np.timedelta64(1,'D')


clean_data.head()
# Out:
#                                           Название  \
# 0      Крытый плавательный бассейн «Садко» СДЮСШОР
# 1                  Спортивный зал для мини-футбола
# 2                            Ледовый дворец спорта
# 3        Спортивный центр с плавательным бассейном
# 4  Спортивный центр с универсальным игровым залом
#
#                                                Адрес  \
# 0  Ханты-Мансийский автономный округ, г. Советски...
# 1  Ханты-Мансийский автономный округ, г. Лангепас...
# 2  Ханты - Мансийский автономный округ, г. Сургут...
# 3  Ханты-Мансийский автономный округ, пос. Лыхма,...
# 4  Ханты-Мансийский автономный округ-Югра, г. Лан...
#
#    Общий объём финансирования (руб.)  \
# 0                       147105000.00
# 1                        83829000.00
# 2                       814724600.00
# 3                       212165000.00
# 4                       143946000.00
#
#                                          Виды спорта    Субъект федерации  \
# 0                                           плавание  Ханты-Мансийский АО
# 1  игровые виды спорта (разное), мини-футбол, общ...  Ханты-Мансийский АО
# 2  аквааэробика, греко-римская борьба, общая физи...  Ханты-Мансийский АО
# 3                             аквааэробика, плавание  Ханты-Мансийский АО
# 4  баскетбол, бодибилдинг, волейбол, настольный т...  Ханты-Мансийский АО
#
#                  Тип спортивного комплекса                 E-mail  \
# 0                                  бассейн          ukmps@mail.ru
# 1                           зал спортивный                    NaN
# 2                            арена ледовая        lds2011@list.ru
# 3  многофункциональный спортивный комплекс  NurtdinovRA@admbel.ru
# 4  многофункциональный спортивный комплекс                    NaN
#
#   Населённый пункт                                   Краткое описание  \
# 0     г. Советский  МБОУ ДОД СДЮСШОР г. Советский единственное учр...
# 1      г. Лангепас  Отдельно стоящее здание, расположено на обособ...
# 2        г. Сургут  Ледовый Дворец спорта в городе Сургуте открыт ...
# 3       пос. Лыхма  Спортивный центр с плавательным бассейном в п....
# 4      г. Лангепас  Отдельно стоящее здание, расположено на обособ...
#
#                                   Детальное описание  ... Почтовый индекс  \
# 0  Общая площадь здания «Крытого плавательного ба...  ...          628240
# 1  Здание кирпичное, бетонное, блоки «Сэндвичи». ...  ...          628671
# 2  Общая площадь объекта составляет 21 247 м2. Пе...  ...          628408
# 3  Общая площадь объекта составляет 2111 м2. Пере...  ...          628173
# 4  Общая площадь объекта составляет 3092,8 м2. Пе...  ...          628672
#
#         Даты крупных соревнований и значимых событий  EUR_today  \
# 0                                               None      82.64
# 1   Финал Кубка России среди юношей 2000г.р. по м...      82.64
# 2   - 05, 06 марта 2013 года – Первенство России ...      82.64
# 3                                               None      82.64
# 4                                               None      82.64
#
#    Общий объём финансирования (EUR)    end_date   USD_date  \
# 0                        1780072.34  31.12.2008      29.38
# 1                        1014388.93  30.12.2009      29.85
# 2                        9858731.68  05.11.2011      30.84
# 3                        2567343.38  24.12.2009      30.50
# 4                        1741846.25  30.12.2011      32.02
#
#    Общий объём финансирования (USD)  \
# 0                        5006909.37
# 1                        2808426.38
# 2                       26414533.88
# 3                        6956069.86
# 4                        4495544.93
#
#   Суммарный объем финансирования - строительство (руб.)  \
# 0                                      2146055710.00
# 1                                      2146055710.00
# 2                                      2146055710.00
# 3                                      2146055710.00
# 4                                      2146055710.00
#
#   Доля от объема финансирования в регионе  \
# 0                                    0.07
# 1                                    0.04
# 2                                    0.38
# 3                                    0.10
# 4                                    0.07
#
#   Продолжительность строительства/реконструкции (дней)
# 0                                             761.00
# 1                                             943.00
# 2                                            1252.00
# 3                                            1105.00
# 4                                            1446.00
#
# [5 rows x 30 columns]

# %%
#проверим
print("Пропуски" ,len(clean_data[clean_data['Продолжительность строительства/реконструкции (дней)'] == 0])
, "+", len(clean_data[clean_data['Продолжительность строительства/реконструкции (дней)'].isna()]))
# Out:
# Пропуски 0 + 117

# %%
# не добавились ли даты без всей информации
clean_data[(clean_data['Продолжительность строительства/реконструкции (дней)'].isna()== False) & ((clean_data[
    'Дата завершения строительства / реконструкции'].isna()) | (clean_data[
    'Дата начала строительства / реконструкции'].isna()))]
# Out:
# Empty DataFrame
# Columns: [Название, Адрес, Общий объём финансирования (руб.), Виды спорта, Субъект федерации, Тип спортивного комплекса, E-mail, Населённый пункт, Краткое описание, Детальное описание, Дата начала строительства / реконструкции, Дата завершения строительства / реконструкции, URL сайта, Финансирование из федерального бюджета, Финансирование из бюджета субъекта федерации, Финансирование из бюджета муниципального образования, Финансирование из внебюджетных источников, Активный, Действия с объектом, Тип населенного пункта, Почтовый индекс, Даты крупных соревнований и значимых событий, EUR_today, Общий объём финансирования (EUR), end_date, USD_date, Общий объём финансирования (USD), Суммарный объем финансирования - строительство (руб.), Доля от объема финансирования в регионе, Продолжительность строительства/реконструкции (дней)]
# Index: []
#
# [0 rows x 30 columns]

# %%
clean_data['Продолжительность строительства/реконструкции (дней)'].describe()
# Out:
# count       693.00
# mean       1027.75
# std         911.43
# min           6.00
# 25%         443.00
# 50%         715.00
# 75%        1294.00
# max        8016.00
# Name: Продолжительность строительства/реконструкции (дней), dtype: float64

# %%
# посмотрм на распределение
# Визуализируем
plt.figure(figsize = (12,5)) 
clean_data['Продолжительность строительства/реконструкции (дней)'].hist(bins = 100, facecolor='y',alpha=0.7, density=True)

sns.set(style="whitegrid")
plt.title('Продолжительность строительства/реконструкции', fontsize=15)
plt.xlabel("дней")
plt.ylabel("Плотность")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Наличие зимних олимписких видов спорта в видах спорта объекта
# <a name="27."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
#найдем виды спорта
url = "https://olympic.ru/team/sport/"
response = requests.get(url, headers=headers, allow_redirects=True)
page_text = ''
if response.status_code == 200:
    page_bs = BS(response.text)
    list_olympic = page_bs.find('ul', {'class': 'treeview-menu'}).text
else:
    print(f'Ошибка! Response code: {response.status_code}')
    print(f'URL: {url}')
    print('--------------')
    
list_olympic = list_olympic.lower().splitlines()
list_olympic[48:]
# Out:
# ['зимние',
#  '',
#  'все',
#  'биатлон',
#  'бобслей',
#  'горнолыжный спорт',
#  'керлинг',
#  'конькобежный спорт',
#  'лыжное двоеборье',
#  'лыжные гонки',
#  'прыжки на лыжах с трамплина',
#  'санный спорт',
#  'скелетон',
#  'сноуборд',
#  'фигурное катание на коньках',
#  'фристайл',
#  'хоккей',
#  'шорт трек',
#  '',
#  '']

# %%
#выделим зимние
list_olympic = list_olympic[51:-2]
list_olympic.sort(reverse=False)
list_olympic
# Out:
# ['биатлон',
#  'бобслей',
#  'горнолыжный спорт',
#  'керлинг',
#  'конькобежный спорт',
#  'лыжное двоеборье',
#  'лыжные гонки',
#  'прыжки на лыжах с трамплина',
#  'санный спорт',
#  'скелетон',
#  'сноуборд',
#  'фигурное катание на коньках',
#  'фристайл',
#  'хоккей',
#  'шорт трек']

# %%
#в добавим фигурное катание, а не 'фигурное катание на коньках'
list_olympic.append('фигурное катание')

# %%
def is_olympic(base):
    try:
        sports = base['Виды спорта'].replace('ё','е')
        sport_list = sports.split(', ')
    except:
        return None
    for s in sport_list:
        if s in list_olympic:
            return True
    return False

clean_data['Наличие зимних олимписких видов спорта в видах спорта объекта'] = clean_data.apply(is_olympic, axis=1)

# %%
# какой процент ?
clean_data['Наличие зимних олимписких видов спорта в видах спорта объекта'].mean()
# Out:
# 0.2123456790123457

# %%
print("Пропуски", len(clean_data[clean_data['Наличие зимних олимписких видов спорта в видах спорта объекта'].isna()]))
# Out:
# Пропуски 0

# %%
clean_data[clean_data['Наличие зимних олимписких видов спорта в видах спорта объекта'] == True].head(3)
# Out:
#                        Название  \
# 2         Ледовый дворец спорта
# 5         Крытый хоккейный корт
# 15  ДЮСШ № 7, отделение футбола
#
#                                                 Адрес  \
# 2   Ханты - Мансийский автономный округ, г. Сургут...
# 5   Хантымансийский АО, пгт Игрим, ул. Промышленна...
# 15     Забайкальский край, г. Чита, ул. Вайнштейна, 3
#
#     Общий объём финансирования (руб.)  \
# 2                        814724600.00
# 5                        250351000.00
# 15                         8450000.00
#
#                                           Виды спорта    Субъект федерации  \
# 2   аквааэробика, греко-римская борьба, общая физи...  Ханты-Мансийский АО
# 5                            фигурное катание, хоккей  Ханты-Мансийский АО
# 15    лёгкая атлетика, футбол, хоккей, хоккей с мячом   Забайкальский край
#
#    Тип спортивного комплекса              E-mail Населённый пункт  \
# 2              арена ледовая     lds2011@list.ru        г. Сургут
# 5              арена ледовая  sk-aisberg@mail.ru        пгт Игрим
# 15          футбольное поле                  NaN          г. Чита
#
#                                      Краткое описание  \
# 2   Ледовый Дворец спорта в городе Сургуте открыт ...
# 5   Наименование учреждения на базе данного спорти...
# 15  На МСК «Темп» проводится огромное количество с...
#
#                                    Детальное описание  ...  \
# 2   Общая площадь объекта составляет 21 247 м2. Пе...  ...
# 5   Общая площадь объекта составляет 4374 м2. Пере...  ...
# 15  Искусственное футбольное поле 3 поколения. Исп...  ...
#
#          Даты крупных соревнований и значимых событий  EUR_today  \
# 2    - 05, 06 марта 2013 года – Первенство России ...      82.64
# 5    Март, Ежегодный детский турнир по хоккею с ша...      82.64
# 15                                               None      82.64
#
#    Общий объём финансирования (EUR)    end_date   USD_date  \
# 2                        9858731.68  05.11.2011      30.84
# 5                        3029420.41  16.09.2014      37.99
# 15                        102250.85  01.12.2009      29.07
#
#     Общий объём финансирования (USD)  \
# 2                        26414533.88
# 5                         6590594.98
# 15                         290690.67
#
#     Суммарный объем финансирования - строительство (руб.)  \
# 2                                       2146055710.00
# 5                                       2146055710.00
# 15                                       613163582.00
#
#    Доля от объема финансирования в регионе  \
# 2                                     0.38
# 5                                     0.12
# 15                                    0.01
#
#    Продолжительность строительства/реконструкции (дней)  \
# 2                                             1252.00
# 5                                             2829.00
# 15                                                nan
#
#    Наличие зимних олимписких видов спорта в видах спорта объекта
# 2                                                True
# 5                                                True
# 15                                               True
#
# [3 rows x 31 columns]

# %% [markdown]
# ### Итог
# <a name="28."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
# уберем рабочие столбцы
clean_data = clean_data[need_columns_extended + diff_list]

# %%
#Выгружаем только необходимые стобцы клиенту
data_sports_facilities = clean_data[client_columns]

# %%
#распечатаем базовую инфо
print_basic_info(data_sports_facilities,1,0,1,0)
# Out:
#   info
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 810 entries, 0 to 809
# Data columns (total 12 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Название                                                       810 non-null    object
#  1   Адрес                                                          810 non-null    object
#  2   Тип населенного пункта                                         810 non-null    object
#  3   Почтовый индекс                                                794 non-null    object
#  4   E-mail                                                         458 non-null    object
#  5   Даты крупных соревнований и значимых событий                   197 non-null    object
#  6   Общий объём финансирования (руб.)                              810 non-null    float64
#  7   Общий объём финансирования (EUR)                               810 non-null    float64
#  8   Общий объём финансирования (USD)                               797 non-null    float64
#  9   Доля от объема финансирования в регионе                        810 non-null    float64
#  10  Продолжительность строительства/реконструкции (дней)           693 non-null    float64
#  11  Наличие зимних олимписких видов спорта в видах спорта объекта  810 non-null    bool
# dtypes: bool(1), float64(5), object(6)
# memory usage: 76.7+ KB
# None
#
#   duplicated
#
# 0

# %%
print_basic_info(data_sports_facilities,0,0,0,5)
# Out:
#   head
#                                           Название  \
# 0      Крытый плавательный бассейн «Садко» СДЮСШОР
# 1                  Спортивный зал для мини-футбола
# 2                            Ледовый дворец спорта
# 3        Спортивный центр с плавательным бассейном
# 4  Спортивный центр с универсальным игровым залом
#
#                                                Адрес Тип населенного пункта  \
# 0  Ханты-Мансийский автономный округ, г. Советски...                  город
# 1  Ханты-Мансийский автономный округ, г. Лангепас...                  город
# 2  Ханты - Мансийский автономный округ, г. Сургут...                  город
# 3  Ханты-Мансийский автономный округ, пос. Лыхма,...                посёлок
# 4  Ханты-Мансийский автономный округ-Югра, г. Лан...                  город
#
#   Почтовый индекс                 E-mail  \
# 0          628240          ukmps@mail.ru
# 1          628671                    NaN
# 2          628408        lds2011@list.ru
# 3          628173  NurtdinovRA@admbel.ru
# 4          628672                    NaN
#
#         Даты крупных соревнований и значимых событий  \
# 0                                               None
# 1   Финал Кубка России среди юношей 2000г.р. по м...
# 2   - 05, 06 марта 2013 года – Первенство России ...
# 3                                               None
# 4                                               None
#
#    Общий объём финансирования (руб.)  Общий объём финансирования (EUR)  \
# 0                       147105000.00                        1780072.34
# 1                        83829000.00                        1014388.93
# 2                       814724600.00                        9858731.68
# 3                       212165000.00                        2567343.38
# 4                       143946000.00                        1741846.25
#
#    Общий объём финансирования (USD)  Доля от объема финансирования в регионе  \
# 0                        5006909.37                                     0.07
# 1                        2808426.38                                     0.04
# 2                       26414533.88                                     0.38
# 3                        6956069.86                                     0.10
# 4                        4495544.93                                     0.07
#
#    Продолжительность строительства/реконструкции (дней)  \
# 0                                             761.00
# 1                                             943.00
# 2                                            1252.00
# 3                                            1105.00
# 4                                            1446.00
#
#    Наличие зимних олимписких видов спорта в видах спорта объекта
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                              False

# %%
#сохраняем 

data_sports_facilities.to_csv('data_sports_facilities.csv', index=False)

# %% [markdown]
# ## 3. Отчет по субъектам федерации:
# <a name="3."></a>
# ####  "Суммарный объем финансирования - строительство (руб.)"
# <a name="31."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
# Расчеты уже есть. Проверим заполненность

print('Пропусков:',len(sub_sum[sub_sum['Суммарный объем финансирования - строительство (руб.)'].isna()]))

sub_sum
# Out:
# Пропусков: 0
#         Субъект федерации  \
# 0          Алтайский край
# 1        Амурская область
# 2   Архангельская область
# 3    Астраханская область
# 4    Белгородская область
# ..                    ...
# 77    Ханты-Мансийский АО
# 78    Челябинская область
# 79   Чеченская Республика
# 80      Ямало-Ненецкий АО
# 81    Ярославская область
#
#     Суммарный объем финансирования - строительство (руб.)
# 0                                        465988021.00
# 1                                        243921000.00
# 2                                        922821600.00
# 3                                       2924360433.00
# 4                                        871190000.00
# ..                                                ...
# 77                                      2146055710.00
# 78                                       438272022.00
# 79                                       374569000.00
# 80                                        18000000.00
# 81                                      1229190000.00
#
# [82 rows x 2 columns]

# %% [markdown]
# ####  Количество спортивных объектов
# <a name="32."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
# Расчеты

sub_count = clean_data.groupby(['Субъект федерации'])['Адрес'].count().reset_index()
sub_count.columns = ['Субъект федерации', 'Количество спортивных объектов']

# %%
# Проверка

print('Пропусков:',len(sub_count[sub_count['Количество спортивных объектов'].isna()]))

sub_count
# Out:
# Пропусков: 0
#         Субъект федерации  Количество спортивных объектов
# 0          Алтайский край                               5
# 1        Амурская область                               3
# 2   Архангельская область                               5
# 3    Астраханская область                              12
# 4    Белгородская область                              13
# ..                    ...                             ...
# 77    Ханты-Мансийский АО                               7
# 78    Челябинская область                               5
# 79   Чеченская Республика                               7
# 80      Ямало-Ненецкий АО                               1
# 81    Ярославская область                               9
#
# [82 rows x 2 columns]

# %% [markdown]
# ####  Перечень типов спортивных объеков
# <a name="33."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
# Расчеты

sub_types = clean_data.groupby(['Субъект федерации'])['Тип спортивного комплекса'].unique().reset_index()
sub_types.columns = ['Субъект федерации', 'Перечень типов спортивных объеков']

# %%
def sort_inside(base):
    lst= base['Перечень типов спортивных объеков']
    try: 
        lst_s = list(sorted(set(lst)))
        return lst_s
    except:
        return None
        
sub_types['Перечень типов спортивных объеков'] = sub_types.apply(sort_inside, axis=1)

# %%
# Проверка

print('Пропусков:',len(sub_types[sub_types['Перечень типов спортивных объеков'].isna()]))

sub_types
# Out:
# Пропусков: 0
#         Субъект федерации                  Перечень типов спортивных объеков
# 0          Алтайский край  [бассейн, многофункциональный спортивный компл...
# 1        Амурская область          [многофункциональный спортивный комплекс]
# 2   Архангельская область  [арена ледовая, бассейн, многофункциональный с...
# 3    Астраханская область  [многофункциональный спортивный комплекс, стад...
# 4    Белгородская область  [арена ледовая, бассейн, зал спортивный, много...
# ..                    ...                                                ...
# 77    Ханты-Мансийский АО  [арена ледовая, бассейн, зал спортивный, много...
# 78    Челябинская область  [бассейн, зал спортивный, манеж легкоатлетичес...
# 79   Чеченская Республика  [многофункциональный спортивный комплекс, футб...
# 80      Ямало-Ненецкий АО                                    [арена ледовая]
# 81    Ярославская область  [арена ледовая, бассейн, комплекс конно-спорти...
#
# [82 rows x 2 columns]

# %% [markdown]
# ####  ТОП-5 доступных видов спорта
# <a name="34."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
# расчет

def top5_sports(base):
    region = base['Субъект федерации']
    # выделим только наш регион
    tmp_base = clean_data[clean_data['Субъект федерации'] == region]
    
    # добавим все виды спорта
    all_sports = []
    for i in range(0,len(tmp_base)):
        try:
            sports = tmp_base.iloc[i]['Виды спорта']
            sport_list = sports.split(', ')
            for s in sport_list:
                all_sports.append(s)
        except:
            next
    #группируем, сортируем и ищем 5 доступных
    cnt = dict(Counter(all_sports))
    big_set = sorted(set(cnt.values()), reverse= True)
    l_top5 = list(itertools.islice(big_set, 5))
    # ловим все подходящие
    d_top5 = {}
    for l in l_top5:
        for key, value in cnt.items(): 
            if l==value:
                d_top5[key]=value
    return d_top5


sub_types['ТОП-5 доступных видов спорта'] = sub_types.apply(top5_sports, axis=1)

# %%
# проверяем

print('Пропусков:',len(sub_types[sub_types['ТОП-5 доступных видов спорта'].isna()]))

sub_types
# Out:
# Пропусков: 0
#         Субъект федерации                  Перечень типов спортивных объеков  \
# 0          Алтайский край  [бассейн, многофункциональный спортивный компл...
# 1        Амурская область          [многофункциональный спортивный комплекс]
# 2   Архангельская область  [арена ледовая, бассейн, многофункциональный с...
# 3    Астраханская область  [многофункциональный спортивный комплекс, стад...
# 4    Белгородская область  [арена ледовая, бассейн, зал спортивный, много...
# ..                    ...                                                ...
# 77    Ханты-Мансийский АО  [арена ледовая, бассейн, зал спортивный, много...
# 78    Челябинская область  [бассейн, зал спортивный, манеж легкоатлетичес...
# 79   Чеченская Республика  [многофункциональный спортивный комплекс, футб...
# 80      Ямало-Ненецкий АО                                    [арена ледовая]
# 81    Ярославская область  [арена ледовая, бассейн, комплекс конно-спорти...
#
#                          ТОП-5 доступных видов спорта
# 0   {'плавание': 4, 'игровые виды спорта (разное)'...
# 1   {'плавание': 2, 'вольная борьба': 1, 'настольн...
# 2   {'бадминтон': 2, 'баскетбол': 2, 'волейбол': 2...
# 3   {'мини-футбол': 8, 'футбол': 8, 'баскетбол': 7...
# 4   {'футбол': 6, 'плавание': 5, 'баскетбол': 5, '...
# ..                                                ...
# 77  {'плавание': 4, 'общая физическая подготовка':...
# 78  {'бокс': 3, 'бодибилдинг': 2, 'лёгкая атлетика...
# 79  {'бокс': 4, 'футбол': 3, 'восточное боевое еди...
# 80  {'конькобежный спорт': 1, 'фигурное катание': ...
# 81  {'лёгкая атлетика': 5, 'футбол': 5, 'баскетбол...
#
# [82 rows x 3 columns]

# %% [markdown]
# ### Итог
# <a name="35."></a>
# [<font size="1">(к содержанию)</font>](#1common.)

# %%
#сводим
report_subjects_rf = sub_count.merge(sub_sum, on = 'Субъект федерации').merge(sub_types, on = 'Субъект федерации')

# %%
#распечатаем базовую инфо
print_basic_info(report_subjects_rf,1,0,0,0)
# Out:
#   info
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82 entries, 0 to 81
# Data columns (total 5 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Субъект федерации                                      82 non-null     object
#  1   Количество спортивных объектов                         82 non-null     int64
#  2   Суммарный объем финансирования - строительство (руб.)  82 non-null     float64
#  3   Перечень типов спортивных объеков                      82 non-null     object
#  4   ТОП-5 доступных видов спорта                           82 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 3.8+ KB
# None

# %%
print_basic_info(report_subjects_rf,0,0,0,5)
# Out:
#   head
#        Субъект федерации  Количество спортивных объектов  \
# 0         Алтайский край                               5
# 1       Амурская область                               3
# 2  Архангельская область                               5
# 3   Астраханская область                              12
# 4   Белгородская область                              13
#
#    Суммарный объем финансирования - строительство (руб.)  \
# 0                                       465988021.00
# 1                                       243921000.00
# 2                                       922821600.00
# 3                                      2924360433.00
# 4                                       871190000.00
#
#                    Перечень типов спортивных объеков  \
# 0  [бассейн, многофункциональный спортивный компл...
# 1          [многофункциональный спортивный комплекс]
# 2  [арена ледовая, бассейн, многофункциональный с...
# 3  [многофункциональный спортивный комплекс, стад...
# 4  [арена ледовая, бассейн, зал спортивный, много...
#
#                         ТОП-5 доступных видов спорта
# 0  {'плавание': 4, 'игровые виды спорта (разное)'...
# 1  {'плавание': 2, 'вольная борьба': 1, 'настольн...
# 2  {'бадминтон': 2, 'баскетбол': 2, 'волейбол': 2...
# 3  {'мини-футбол': 8, 'футбол': 8, 'баскетбол': 7...
# 4  {'футбол': 6, 'плавание': 5, 'баскетбол': 5, '...

# %%
#сохраняем 
report_subjects_rf.to_csv('report_subjects_rf.csv', index=False)
